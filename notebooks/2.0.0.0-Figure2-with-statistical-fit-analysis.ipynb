# %%
import numpy as np
import fooof
import matplotlib.pyplot as plt
import time
from joblib import Parallel, delayed
import importlib
import mne
import pandas as pd
import seaborn as sns
import CanonParam._temporary_data_loading.load_open_closed_data as locd
import CanonParam._temporary_data_loading.data_utils as du
import CanonParam._temporary_data_loading.epoch_creation as ec

import CanonParam.parameterize_spectra as bandparams
import CanonParam._temporary_data_loading.generate_psd_fits as gpf
importlib.reload(gpf)
# Out:
# <module 'CanonParam._temporary_data_loading.generate_psd_fits' from '/home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/generate_psd_fits.py'>

# %% [markdown]
# # load the data

# %%
out_dict = gpf.main(n_jobs=16, include_spectrums=True, tables_folder='../data/tables') # ~ 7 minutes at 32 jobs, ~8 minutes at 16 jobs
# Out:
# Loading open/closed pathdict for random epochs
# Savepath: /scratch/ap60/mtbi_detection/data/open_closed_segments
# h_freq is None: None, setting h_freq to 0.5*fs_baseline in alt_params
# Found matching params file: /scratch/ap60/mtbi_detection/data/open_closed_segments/params/params6/params.json
# Setting savepath to /scratch/ap60/mtbi_detection/data/open_closed_segments/params/params6
# Found matching params file: /scratch/ap60/mtbi_detection/data/open_closed_segments/params/params6
# Using 82 subjects for train split. 23 subjects from the train split were not found in the open_closed_pathdict
# Creating random epochs for 31 2/82 ... Creating random epochs for 66 1/82 ... Creating random epochs for 154 3/82 ... Creating random epochs for 65 4/82 ... Creating random epochs for 116 7/82 ... Creating random epochs for 64 5/82 ... Creating random epochs for 109 6/82 ... Creating random epochs for 113 9/82 ... Creating random epochs for 114 8/82 ... Creating random epochs for 111 10/82 ... Creating random epochs for 44 11/82 ... Creating random epochs for 99 13/82 ... Creating random epochs for 95 15/82 ... Creating random epochs for 56 12/82 ... Creating random epochs for 61 14/82 ... Creating random epochs for 88 16/82 ...
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
#  finished in 8.446147918701172 seconds
#  finished in 8.391065835952759 seconds
# Creating random epochs for 62 17/82 ...  finished in 8.654256582260132 seconds
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
#  finished in 8.656967163085938 seconds
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
#  finished in 8.759053707122803 seconds
#  finished in 8.849815845489502 seconds
# Creating random epochs for 144 18/82 ... Creating random epochs for 50 19/82 ... Creating random epochs for 138 20/82 ...  finished in 8.975611209869385 seconds
# Creating random epochs for 71 21/82 ... Creating random epochs for 139 22/82 ... Creating random epochs for 115 23/82 ...  finished in 9.315677404403687 seconds
#  finished in 8.990033626556396 seconds
#  finished in 9.051273822784424 seconds
# Creating random epochs for 35 24/82 ...
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# Creating random epochs for 79 25/82 ... Creating random epochs for 24 26/82 ...  finished in 9.184246301651001 seconds
#  finished in 9.345030069351196 seconds
# Creating random epochs for 120 27/82 ...  finished in 9.363178730010986 seconds
# Creating random epochs for 17 28/82 ...
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# Creating random epochs for 157 29/82 ...  finished in 1.171224594116211 seconds
# Creating random epochs for 70 30/82 ...  finished in 9.556776285171509 seconds
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# Creating random epochs for 173 31/82 ...
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
#  finished in 10.062373638153076 seconds
#  finished in 1.2770328521728516 seconds
# Creating random epochs for 25 32/82 ... Creating random epochs for 30 33/82 ...  finished in 1.1662890911102295 seconds
# Creating random epochs for 151 34/82 ...  finished in 1.1872279644012451 seconds
#  finished in 1.2149100303649902 seconds
# Creating random epochs for 126 35/82 ...  finished in 1.399845838546753 seconds
# Creating random epochs for 39 36/82 ... Creating random epochs for 155 37/82 ...  finished in 1.099135398864746 seconds
#  finished in 0.3278956413269043 seconds
# Creating random epochs for 123 38/82 ...  finished in 1.2334132194519043 seconds
# Creating random epochs for 5 39/82 ... Creating random epochs for 32 40/82 ...
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
# /home/ap60/github/CanonParam/CanonParam/_temporary_data_loading/epoch_creation.py:187: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   assert rand_epochs.get_data().shape[0] == epochs_per_subject, f'Expected {epochs_per_subject} epochs, got {rand_epochs.get_data().shape[0]}'
#  finished in
seconds for state closed (2/2) for subj 67 (70/82)
# Finished channel T5 (17/19) in 0.6171126365661621 seconds for state closed (2/2) for subj 67 (70/82)
# Finished channel T6 (18/19) in 0.24370598793029785 seconds for state closed (2/2) for subj 67 (70/82)
# Finished state closed (1/82) in 13.77668809890747 seconds for subj 67 (71/82)
# Finished 67 (70/2) in 127.20698094367981 seconds
# Mean time per channel: 1.1278866525639006
# Mean time per subject: 21.59211905264273
# Finished running all FOOOF in 293.44505190849304 seconds
# FOOOF Mean R squared: 0.9702274186399469, max: 0.9949455279356831, min: 0.48107693063407325
# rsq df mean: 0.9702293898073946, max: 0.9949455279356831, min: 0.48107693063407325

# %%
out_dict.keys()
# Out:
# dict_keys(['param_dfs', 'fooof_param_dfs', 'all_parameterized_spectra', 'all_fooof_parameterized_spectra', 'psd_dict', 'param_spectra_params', 'psd_normalize_kwargs', 'paramtime', 'foooftime', 'psdtime', 'data_params', 'epochs_params', 'normalization_kwargs', 'our_fit_times', 'fooof_fit_times', 'our_fitted_spectra', 'fooof_fitted_spectra'])

# %%
out_dict['fooof_param_dfs']['rsq'].describe()
# Out:
#        C3_open_rsq  C4_open_rsq  Cz_open_rsq  F3_open_rsq  F4_open_rsq  \
# count    82.000000    82.000000    82.000000    82.000000    82.000000
# mean      0.969951     0.967607     0.981840     0.970735     0.963213
# std       0.033669     0.059201     0.012332     0.024510     0.039244
# min       0.732868     0.481077     0.914758     0.865251     0.695322
# 25%       0.967616     0.972698     0.980329     0.969485     0.956940
# 50%       0.978664     0.980318     0.985780     0.977492     0.975130
# 75%       0.985790     0.985430     0.988453     0.984446     0.984471
# max       0.993373     0.991617     0.993625     0.991651     0.993073
#
#        F7_open_rsq  F8_open_rsq  Fp1_open_rsq  Fp2_open_rsq  Fz_open_rsq  ...  \
# count    82.000000    82.000000     82.000000     82.000000    82.000000  ...
# mean      0.961313     0.960807      0.955971      0.956675     0.979609  ...
# std       0.039231     0.032775      0.034438      0.036779     0.012861  ...
# min       0.732997     0.824843      0.850700      0.765659     0.913784  ...
# 25%       0.957500     0.951650      0.945339      0.941284     0.977973  ...
# 50%       0.972957     0.974821      0.967171      0.970431     0.982412  ...
# 75%       0.982160     0.982795      0.980871      0.980208     0.987311  ...
# max       0.992923     0.993705      0.993276      0.991912     0.994403  ...
#
#        Fz_closed_rsq  O1_closed_rsq  O2_closed_rsq  P3_closed_rsq  \
# count      82.000000      82.000000      82.000000      82.000000
# mean        0.980921       0.980910       0.980728       0.979875
# std         0.014793       0.009415       0.009753       0.011875
# min         0.902470       0.939699       0.940122       0.932191
# 25%         0.979797       0.976653       0.976570       0.974887
# 50%         0.984987       0.983724       0.982957       0.983709
# 75%         0.988058       0.987339       0.987064       0.987617
# max         0.994946       0.992847       0.993518       0.993395
#
#        P4_closed_rsq  Pz_closed_rsq  T3_closed_rsq  T4_closed_rsq  \
# count      82.000000      82.000000      82.000000      82.000000
# mean        0.979869       0.980528       0.961119       0.960794
# std         0.014236       0.012988       0.045932       0.047689
# min         0.901080       0.925633       0.702478       0.673270
# 25%         0.977752       0.979479       0.964653       0.966488
# 50%         0.984073       0.985095       0.975335       0.975282
# 75%         0.987018       0.987310       0.981588       0.982574
# max         0.991690       0.993547       0.989074       0.991603
#
#        T5_closed_rsq  T6_closed_rsq
# count      82.000000      82.000000
# mean        0.971172       0.972494
# std         0.027418       0.023797
# min         0.817051       0.845842
# 25%         0.971277       0.970678
#  72           41.167226          124.500000            0.211129
#  27           59.724821          243.450792            0.148139
#
#       T6_closed_5_width  T6_closed_6_center  T6_closed_6_height  \
#  66           58.632574                 NaN                 NaN
#  31            2.045821                 NaN                 NaN
#  154                NaN                 NaN                 NaN
#  65            2.000000                 NaN                 NaN
#  64            2.000000                 NaN                 NaN
#  ..                 ...                 ...                 ...
#  176           6.823116                 NaN                 NaN
#  90            2.001833                 NaN                 NaN
#  122          59.976969                 NaN                 NaN
#  72           77.786848                 NaN                 NaN
#  27           12.034822                 NaN                 NaN
#
#       T6_closed_6_width
#  66                 NaN
#  31                 NaN
#  154                NaN
#  65                 NaN
#  64                 NaN
#  ..                 ...
#  176                NaN
#  90                 NaN
#  122                NaN
#  72                 NaN
#  27                 NaN
#
#  [82 rows x 988 columns],
#  'full_tensor': array([[[ 1.23965576e+01,  1.08198392e+12,  5.71333765e+00, ...,
#                       nan,             nan,             nan],
#          [ 1.16003133e+01,  1.85915879e+11,  5.31505618e+00, ...,
#                       nan,             nan,             nan],
#          [ 3.42826116e+00, -3.67963952e-02,  1.80921053e+00, ...,
#                       nan,             nan,             nan],
#          ...,
#          [ 2.37019963e+00, -1.89986608e-01,  1.37622466e+00, ...,
#                       nan,             nan,             nan],
#          [ 2.55921526e+00, -1.05635820e-01,  1.45150121e+00, ...,
#                       nan,             nan,             nan],
#          [ 1.68933012e+00, -2.55563544e-01,  1.11006130e+00, ...,
#                       nan,             nan,             nan]],
#
#         [[ 9.96556062e+00,  3.27400998e+09,  4.54953932e+00, ...,
#                       nan,             nan,             nan],
#          [ 1.11163841e+01,  4.82230738e+10,  5.04150815e+00, ...,
#                       nan,             nan,             nan],
#          [ 2.81876444e+00,  4.96718219e+00,  1.49524355e+00, ...,
#                       nan,             nan,             nan],
#          ...,
#          [ 9.15663244e+00,  6.32783188e+08,  4.29591572e+00, ...,
#                       nan,             nan,             nan],
#          [ 9.65770930e+00,  1.51545578e+09,  4.43240404e+00, ...,
#                       nan,             nan,             nan],
#          [ 1.09581305e+01,  4.68112646e+10,  5.08543085e+00, ...,
#                       nan,             nan,             nan]],
#
#         [[ 7.41432953e+00,  8.13814544e+06,  3.46737290e+00, ...,
#                       nan,             nan,             nan],
#          [ 7.99015592e+00,  2.70198270e+07,  3.72910029e+00, ...,
#                       nan,             nan,             nan],
#          [ 6.02133364e+00,  1.42755896e+05,  2.84574517e+00, ...,
#                       nan,             nan,             nan],
#          ...,
#          [ 1.10136126e+01,  5.45533577e+10,  5.08659481e+00, ...,
#                       nan,             nan,             nan],
#          [ 1.02954206e+01,  7.43448135e+09,  4.78665102e+00, ...,
#                       nan,             nan,             nan],
#          [ 1.07671385e+01,  2.88653850e+10,  4.99692262e+00, ...,
#                       nan,             nan,             nan]],
#
#         ...,
#
#         [[ 3.78277346e+00,  1.19347332e+02,  1.90347159e+00, ...,
#                       nan,             nan,             nan],
#          [ 4.44882076e+00,  2.77442493e+03,  2.15564702e+00, ...,
#                       nan,             nan,             nan],
#          [ 4.08015602e+00,  5.70213555e+02,  1.96187564e+00, ...,
#                       nan,             nan,             nan],
#          ...,
#          [ 6.21411618e+00,  3.58196144e+05,  2.94941032e+00, ...,
#                       nan,             nan,             nan],
#          [ 3.67918204e+00,  8.37789476e+01,  1.80270649e+00, ...,
#                       nan,             nan,             nan],
#          [ 3.76778065e+00,  2.00129455e+02,  1.87429249e+00, ...,
#                       nan,             nan,             nan]],
#
#         [[ 3.63510943e+00,  8.43960667e+00,  1.84415736e+00, ...,
#                       nan,             nan,             nan],
#          [ 3.00654475e+00,  5.22868785e+00,  1.55952375e+00, ...,
#                       nan,             nan,             nan],
#          [ 3.62415618e+00,  2.91432783e+00,  1.84861201e+00, ...,
#                       nan,             nan,             nan],
#          ...,
#          [ 5.54965307e+00,  7.37447638e+04,  2.66767348e+00, ...,
#                       nan,             nan,             nan],
#          [ 3.42182527e+00,  1.08997452e+01,  1.77722295e+00, ...,
#            1.09100000e+02,  3.22292016e-01,  6.72145408e+01],
#          [ 3.20123004e+00,  2.97040126e+00,  1.63374295e+00, ...,
#                       nan,             nan,             nan]],
#
#         [[ 5.81187977e+00,  1.07880138e+05,  2.76697257e+00, ...,
#                       nan,             nan,             nan],
#          [ 6.68448709e+00,  9.80478571e+05,  3.14400776e+00, ...,
#                       nan,             nan,             nan],
#          [ 4.26437297e+00,  1.49524328e+03,  2.06460565e+00, ...,
#                       nan,             nan,             nan],
#          ...,
#          [ 7.53543451e+00,  1.22975884e+07,  3.52945223e+00, ...,
#                       nan,             nan,             nan],
#          [ 6.71783100e+00,  1.24997986e+06,  3.17303818e+00, ...,
#                       nan,             nan,             nan],
#          [ 7.17236285e+00,  4.06817390e+06,  3.36933453e+00, ...,
#                       nan,             nan,             nan]]]),
#  'tensor_axis1': ['C3_open',
#   'C4_open',
#   'Cz_open',
#   'F3_open',
#   'F4_open',
#   'F7_open',
#   'F8_open',
#   'Fp1_open',
#   'Fp2_open',
#   'Fz_open',
#   'O1_open',
#   'O2_open',
#   'P3_open',
#   'P4_open',
#   'Pz_open',
#   'T3_open',
#   'T4_open',
#   'T5_open',
#   'T6_open',
#   'C3_closed',
#   'C4_closed',
#   'Cz_closed',
#   'F3_closed',
#   'F4_closed',
#   'F7_closed',
#   'F8_closed',
#   'Fp1_closed',
#   'Fp2_closed',
#   'Fz_closed',
#   'O1_closed',
#   'O2_closed',
#   'P3_closed',
#   'P4_closed',
#   'Pz_closed',
#   'T3_closed',
#   'T4_closed',
#   'T5_closed',
#   'T6_closed'],
#  'tensor_axis2': ['rsq',
#   'error',
#   'offset',
#   'knee',
#   'exponent',
#   'peak0_center',
#   'peak0_height',
#   'peak0_width',
#   'peak1_center',
#   'peak1_height',
#   'peak1_width',
#   'peak2_center',
#   'peak2_height',
#   'peak2_width',
#   'peak3_center',
#   'peak3_height',
#   'peak3_width',
#   'peak4_center',
#   'peak4_height',
#   'peak4_width',
#   'peak5_center',
#   'peak5_height',
#   'peak5_width',
#   'peak6_center',
#   'peak6_height',
#   'peak6_width']}

# %% [markdown]
# # unpack the fits

# %%
fooof_param_dfs = out_dict['fooof_param_dfs']
our_param_dfs = out_dict['param_dfs']

fooof_rmse_df = fooof_param_dfs['error']
our_rmse_df = our_param_dfs['error']
fooof_rsq_df = fooof_param_dfs['rsq']
our_rsq_df = our_param_dfs['rsq']

# %%
all_train_subjs = out_dict['psd_dict'].keys()
channels = out_dict['psd_dict'][list(all_train_subjs)[0]]['open'].ch_names

# %%
# show the nans in fooof_rmse_df
fooof_rmse_df.loc[fooof_rmse_df.isna().any(axis=1), fooof_rmse_df.isna().any(axis=0)]
# Out:
#     O1_open_mse
# 67          NaN

# %%
our_rmse_df.loc[our_rmse_df.isna().any(axis=1), our_rmse_df.isna().any(axis=0)]
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Wilcoxon Signed Rank and T-test

# %%
fooof_avgrmse = fooof_rmse_df.mean(axis=1)
our_avgrmse = our_rmse_df.mean(axis=1).loc[fooof_avgrmse.index]

# plot these two as histograms
plt.hist(fooof_avgrmse, bins=20, alpha=0.5, label='SpecParam')
plt.hist(our_avgrmse, bins=20, alpha=0.5, label='Our Method')
plt.title('Average RMSE')
plt.xlabel('RMSE')
plt.ylabel('Number of Subjects')
plt.legend()


# run a wilcoxon signed rank test and permutation matched pairs t-test
from scipy.stats import wilcoxon, ttest_rel
print(wilcoxon(fooof_avgrmse, our_avgrmse, alternative='greater'))
avgrmse_pval = wilcoxon(fooof_avgrmse, our_avgrmse, alternative='greater')[1]
avgrmse_ttest = ttest_rel(fooof_avgrmse, our_avgrmse, alternative='greater')
print(ttest_rel(fooof_avgrmse, our_avgrmse, alternative='greater'))

print("Median and IQR of SpecParam RMSE: ", np.median(fooof_avgrmse), np.percentile(fooof_avgrmse, 25), np.percentile(fooof_avgrmse, 75))
print("Median and IQR of Our Method RMSE: ", np.median(our_avgrmse), np.percentile(our_avgrmse, 25), np.percentile(our_avgrmse, 75))
print(f"Mean and SEM of SpecParam RMSE: {fooof_avgrmse.mean()} +/- {fooof_avgrmse.sem()}")
print(f"Mean and SEM of Our Method RMSE: {our_avgrmse.mean()} +/- {our_avgrmse.sem()}")
# Out:
# WilcoxonResult(statistic=3309.0, pvalue=5.3740878719829113e-14)
# TtestResult(statistic=13.378260598785484, pvalue=1.6322210344132912e-22, df=81)
# Median and IQR of SpecParam RMSE:  0.09606958903939516 0.08332389675672422 0.11064388385174995
# Median and IQR of Our Method RMSE:  0.07869343217459472 0.07003250196872762 0.09623423443226804
# Mean and SEM of SpecParam RMSE: 0.10160474063646607 +/- 0.0026448047161871033
# Mean and SEM of Our Method RMSE: 0.0855356455577943 +/- 0.002529414445782718
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[77], line 24
#      22 print(f"Mean and SEM of SpecParam RMSE: {fooof_avgrmse.mean()} +/- {fooof_avgrmse.sem()}")
#      23 print(f"Mean and SEM of Our Method RMSE: {our_avgrmse.mean()} +/- {our_avgrmse.sem()}")
# ---> 24 print(f"N = {len(fooof_avgrmse) * fooof_avgrmse.shape[1]}")
#
# IndexError: tuple index out of range

# %%
fooof_avgrmse
# Out:
# 66     0.173476
# 31     0.121155
# 154    0.094464
# 65     0.106140
# 64     0.144110
#          ...
# 176    0.116614
# 90     0.095768
# 122    0.069246
# 72     0.098784
# 27     0.084411
# Length: 82, dtype: float64

# %%
# show all the r squared values greater than 1
weird_rsq = np.where(fooof_rsq_df > 1)
for i in range(len(weird_rsq[0])):
    print(f"Subj: {np.array(fooof_rsq_df.index)[weird_rsq[0][i]]}, Channel: {channels[weird_rsq[1][i]//2]}, State: {'open' if weird_rsq[1][i] % 2 == 0 else 'closed'}")
    print(f"R squared: {fooof_rsq_df.iloc[weird_rsq[0][i], weird_rsq[1][i]]}")

# %%
fooof_avgrsq = fooof_rsq_df.mean(axis=1)
our_avgrsq = our_rsq_df.mean(axis=1).loc[fooof_avgrsq.index]

# plot these two as histograms
plt.hist(fooof_avgrsq, bins=20, alpha=0.5, label='SpecParam')
plt.hist(our_avgrsq, bins=20, alpha=0.5, label='Our Method')
plt.title('Average R-Squared')
plt.xlabel('R-Squared')
plt.ylabel('Number of Subjects')
plt.legend()

# run a wilcoxon signed rank test and permutation matched pairs t-test
print(wilcoxon(fooof_avgrsq, our_avgrsq, alternative='less'))
avgrsq_pval = wilcoxon(fooof_avgrsq, our_avgrsq, alternative='less')[1]
print(ttest_rel(fooof_avgrsq, our_avgrsq, alternative='less'))
avgrsq_ttest = ttest_rel(fooof_avgrsq, our_avgrsq, alternative='less')

print(f"Median and IQR of R squared values for SpecParam: {np.median(fooof_avgrsq)}, {np.percentile(fooof_avgrsq, 25)}, {np.percentile(fooof_avgrsq, 75)}")
print(f"Median and IQR of R squared values for Our Method: {np.median(our_avgrsq)}, {np.percentile(our_avgrsq, 25)}, {np.percentile(our_avgrsq, 75)}")
print(f"Mean and SEM of R squared values for SpecParam: {np.mean(fooof_avgrsq)}, {np.std(fooof_avgrsq)/np.sqrt(len(fooof_avgrsq))}")
print(f"Mean and SEM of R squared values for Our Method: {np.mean(our_avgrsq)}, {np.std(our_avgrsq)/np.sqrt(len(our_avgrsq))}")
# Out:
# WilcoxonResult(statistic=128.0, pvalue=1.7425728494314134e-13)
# TtestResult(statistic=-9.261866765428051, pvalue=1.2063560294417978e-14, df=81)
# Median and IQR of R squared values for SpecParam: 0.9770481966376892, 0.9683672152272161, 0.9810517200639025
# Median and IQR of R squared values for Our Method: 0.985134125589767, 0.9799594577814197, 0.9879037630411929
# Mean and SEM of R squared values for SpecParam: 0.9702277049282888, 0.00215902775667674
# Mean and SEM of R squared values for Our Method: 0.9789983386827019, 0.0018501269772845347

# %% [markdown]
# ## open vs closed

# %%
open_fooof_armse = fooof_rmse_df[[col for col in fooof_rmse_df.columns if 'open' in col]].mean(axis=1)
closed_fooof_armse = fooof_rmse_df[[col for col in fooof_rmse_df.columns if 'closed' in col]].mean(axis=1)
open_our_armse = our_rmse_df[[col for col in our_rmse_df.columns if 'open' in col]].mean(axis=1)
closed_our_armse = our_rmse_df[[col for col in our_rmse_df.columns if 'closed' in col]].mean(axis=1)

fig, axs = plt.subplots(1,2, figsize=(12,4))
axs[0].hist(open_fooof_armse, bins=20, alpha=0.5, label='SpecParam')
axs[0].hist(open_our_armse, bins=20, alpha=0.5, label='Our Method')
axs[0].set_title('Open Eyes RMSE')
axs[0].set_xlabel('RMSE')
axs[0].set_ylabel('Number of Subjects')
axs[0].legend()
axs[1].hist(closed_fooof_armse, bins=20, alpha=0.5, label='SpecParam')
axs[1].hist(closed_our_armse, bins=20, alpha=0.5, label='Our Method')
axs[1].set_title('Closed Eyes RMSE')
axs[1].set_xlabel('RMSE')
axs[1].set_ylabel('Number of Subjects')
axs[1].legend()

plt.show()

open_wilcoxon = wilcoxon(open_fooof_armse, open_our_armse, alternative='greater')
closed_wilcoxon = wilcoxon(closed_fooof_armse, closed_our_armse, alternative='greater')

# holm-bonferroni correction
print(open_wilcoxon)
print(closed_wilcoxon)
from statsmodels.stats.multitest import multipletests
adjusted_pvals = multipletests([open_wilcoxon.pvalue, closed_wilcoxon.pvalue], method='holm')
print(f"Adjusted p-values: {adjusted_pvals[1]}")


open_ttest = ttest_rel(open_fooof_armse, open_our_armse, alternative='greater')
closed_ttest = ttest_rel(closed_fooof_armse, closed_our_armse, alternative='greater')
print(open_ttest)
print(closed_ttest)
adjusted_tpvals = multipletests([open_ttest.pvalue, closed_ttest.pvalue], method='holm')
print(f"Adjusted p-values: {adjusted_tpvals[1]}")

print(f"Open Median and IQR of SpecParam RMSE: {np.median(open_fooof_armse)}, {np.percentile(open_fooof_armse, 25)}, {np.percentile(open_fooof_armse, 75)}")
print(f"Open Median and IQR of Our Method RMSE: {np.median(open_our_armse)}, {np.percentile(open_our_armse, 25)}, {np.percentile(open_our_armse, 75)}")
print(f"Open Mean and SEM of SpecParam RMSE: {np.mean(open_fooof_armse)}, {np.std(open_fooof_armse)/np.sqrt(len(open_fooof_armse))}")
print(f"Open Mean and SEM of Our Method RMSE: {np.mean(open_our_armse)}, {np.std(open_our_armse)/np.sqrt(len(open_our_armse))}")
print(f"Closed Median and IQR of SpecParam RMSE: {np.median(closed_fooof_armse)}, {np.percentile(closed_fooof_armse, 25)}, {np.percentile(closed_fooof_armse, 75)}")
print(f"Closed Median and IQR of Our Method RMSE: {np.median(closed_our_armse)}, {np.percentile(closed_our_armse, 25)}, {np.percentile(closed_our_armse, 75)}")
print(f"Closed Mean and SEM of SpecParam RMSE: {np.mean(closed_fooof_armse)}, {np.std(closed_fooof_armse)/np.sqrt(len(closed_fooof_armse))}")
print(f"Closed Mean and SEM of Our Method RMSE: {np.mean(closed_our_armse)}, {np.std(closed_our_armse)/np.sqrt(len(closed_our_armse))}")
# Out:
# WilcoxonResult(statistic=3321.0, pvalue=3.527545587598112e-14)
# WilcoxonResult(statistic=3299.0, pvalue=7.614837230612983e-14)
# Adjusted p-values: [7.05509118e-14 7.61483723e-14]
# TtestResult(statistic=10.491921078782172, pvalue=4.631253174028813e-17, df=81)
# TtestResult(statistic=12.338612711426983, pvalue=1.3574986521831847e-20, df=81)
# Adjusted p-values: [4.63125317e-17 2.71499730e-20]
# Open Median and IQR of SpecParam RMSE: 0.09613006150166889, 0.08533720384002294, 0.11014817760301131
# Open Median and IQR of Our Method RMSE: 0.0748284712869474, 0.06574268715421558, 0.08659910118153964
# Open Mean and SEM of SpecParam RMSE: 0.10220293663413076, 0.002957273732015843
# Open Mean and SEM of Our Method RMSE: 0.08252839406671195, 0.003048209336871863
# Closed Median and IQR of SpecParam RMSE: 0.09199127831246365, 0.08307050414006449, 0.10713251154588643
# Closed Median and IQR of Our Method RMSE: 0.08114451471911707, 0.07101863916221302, 0.09563933285422233
# Closed Mean and SEM of SpecParam RMSE: 0.10100635274424846, 0.0030923761555359214
# Closed Mean and SEM of Our Method RMSE: 0.08854289704887668, 0.002923507865190081

# %%
open_fooof_arsq = fooof_rsq_df[[col for col in fooof_rsq_df.columns if 'open' in col]].mean(axis=1)
closed_fooof_arsq = fooof_rsq_df[[col for col in fooof_rsq_df.columns if 'closed' in col]].mean(axis=1)
open_our_arsq = our_rsq_df[[col for col in our_rsq_df.columns if 'open' in col]].mean(axis=1)
closed_our_arsq = our_rsq_df[[col for col in our_rsq_df.columns if 'closed' in col]].mean(axis=1)

fig, axs = plt.subplots(1,2, figsize=(12,4))
axs[0].hist(open_fooof_arsq, bins=20, alpha=0.5, label='SpecParam')
axs[0].hist(open_our_arsq, bins=20, alpha=0.5, label='Our Method')
axs[0].set_title('Open Eyes R-Squared')
axs[0].set_xlabel('R-Squared')
axs[0].set_ylabel('Number of Subjects')
axs[0].legend()
axs[1].hist(closed_fooof_arsq, bins=20, alpha=0.5, label='SpecParam')
axs[1].hist(closed_our_arsq, bins=20, alpha=0.5, label='Our Method')
axs[1].set_title('Closed Eyes R-Squared')
axs[1].set_xlabel('R-Squared')
axs[1].set_ylabel('Number of Subjects')
axs[1].legend()

plt.show()

open_wilcoxon_rsq = wilcoxon(open_fooof_arsq, open_our_arsq, alternative='less')
closed_wilcoxon_rsq = wilcoxon(closed_fooof_arsq, closed_our_arsq, alternative='less')

# holm-bonferroni correction
print(open_wilcoxon_rsq)
print(closed_wilcoxon_rsq)
adjusted_pvals_rsq = multipletests([open_wilcoxon_rsq.pvalue, closed_wilcoxon_rsq.pvalue], method='holm')
print(f"Adjusted p-values: {adjusted_pvals_rsq[1]}")

open_ttest_rsq = ttest_rel(open_fooof_arsq, open_our_arsq, alternative='less')
closed_ttest_rsq = ttest_rel(closed_fooof_arsq, closed_our_arsq, alternative='less')
print(open_ttest_rsq)
print(closed_ttest_rsq)
adjusted_tpvals_rsq = multipletests([open_ttest_rsq.pvalue, closed_ttest_rsq.pvalue], method='holm')
print(f"Adjusted p-values: {adjusted_tpvals_rsq[1]}")


print(f"Open Median and IQR of SpecParam R-Squared: {np.median(open_fooof_arsq)}, {np.percentile(open_fooof_arsq, 25)}, {np.percentile(open_fooof_arsq, 75)}")
print(f"Open Median and IQR of Our Method R-Squared: {np.median(open_our_arsq)}, {np.percentile(open_our_arsq, 25)}, {np.percentile(open_our_arsq, 75)}")
print(f"Open Mean and SEM of SpecParam R-Squared: {open_fooof_arsq.mean()} +/- {open_fooof_arsq.sem()}")
print(f"Open Mean and SEM of Our Method R-Squared: {open_our_arsq.mean()} +/- {open_our_arsq.sem()}")

print(f"Closed Median and IQR of SpecParam R-Squared: {np.median(closed_fooof_arsq)}, {np.percentile(closed_fooof_arsq, 25)}, {np.percentile(closed_fooof_arsq, 75)}")
print(f"Closed Median and IQR of Our Method R-Squared: {np.median(closed_our_arsq)}, {np.percentile(closed_our_arsq, 25)}, {np.percentile(closed_our_arsq, 75)}")
print(f"Closed Mean and SEM of SpecParam R-Squared: {closed_fooof_arsq.mean()} +/- {closed_fooof_arsq.sem()}")
print(f"Closed Mean and SEM of Our Method R-Squared: {closed_our_arsq.mean()} +/- {closed_our_arsq.sem()}")
# Out:
# WilcoxonResult(statistic=82.0, pvalue=3.527545587598112e-14)
# WilcoxonResult(statistic=170.0, pvalue=7.206519302620427e-13)
# Adjusted p-values: [7.05509118e-14 7.20651930e-13]
# TtestResult(statistic=-7.979996787448188, pvalue=4.113030090391417e-12, df=81)
# TtestResult(statistic=-7.640413269734361, pvalue=1.9114283692042988e-11, df=81)
# Adjusted p-values: [8.22606018e-12 1.91142837e-11]
# Open Median and IQR of SpecParam R-Squared: 0.9743416589659895, 0.9646942525362407, 0.981498889789097
# Open Median and IQR of Our Method R-Squared: 0.9858743664774124, 0.9800891314567537, 0.9886473962003712
# Open Mean and SEM of SpecParam R-Squared: 0.9678764681427408 +/- 0.0029985310160664034
# Open Mean and SEM of Our Method R-Squared: 0.9791446437070914 +/- 0.002703394927136981
# Closed Median and IQR of SpecParam R-Squared: 0.9807817567912873, 0.9747511085392833, 0.9835422158105145
# Closed Median and IQR of Our Method R-Squared: 0.9861713746394225, 0.9803438855348543, 0.9883412007732787
# Closed Mean and SEM of SpecParam R-Squared: 0.9725810977400007 +/- 0.002652857018746693
# Closed Mean and SEM of Our Method R-Squared: 0.9788520336583127 +/- 0.0023627563018192178

# %% [markdown]
# ## channel by channel

# %%
our_rsq_df.describe()
# Out:
#        C3_open_rsq  C4_open_rsq  Cz_open_rsq  F3_open_rsq  F4_open_rsq  \
# count    82.000000    82.000000    82.000000    82.000000    82.000000
# mean      0.975929     0.974246     0.984425     0.980192     0.979242
# std       0.028849     0.055195     0.015597     0.021487     0.027311
# min       0.807149     0.510138     0.864648     0.864042     0.779859
# 25%       0.977510     0.979143     0.983867     0.982941     0.979639
# 50%       0.984602     0.986257     0.988241     0.986160     0.986016
# 75%       0.988943     0.988912     0.990269     0.989847     0.989731
# max       0.993493     0.993572     0.995344     0.993120     0.993949
#
#        F7_open_rsq  F8_open_rsq  Fp1_open_rsq  Fp2_open_rsq  Fz_open_rsq  ...  \
# count    82.000000    82.000000     82.000000     82.000000    82.000000  ...
# mean      0.978880     0.979146      0.980225      0.980734     0.985236  ...
# std       0.023027     0.020678      0.019910      0.022441     0.011078  ...
# min       0.854822     0.848832      0.871518      0.816551     0.915125  ...
# 25%       0.979496     0.978434      0.978592      0.981382     0.983329  ...
# 50%       0.986274     0.985906      0.986785      0.987285     0.988101  ...
# 75%       0.989758     0.989827      0.989716      0.989434     0.990702  ...
# max       0.994059     0.993856      0.992903      0.993751     0.995403  ...
#
#        Fz_closed_rsq  O1_closed_rsq  O2_closed_rsq  P3_closed_rsq  \
# count      82.000000      82.000000      82.000000      82.000000
# mean        0.983513       0.984984       0.984762       0.983571
# std         0.015097       0.007385       0.008308       0.010336
# min         0.900569       0.946361       0.947327       0.938007
# 25%         0.984420       0.980460       0.983295       0.980985
# 50%         0.988060       0.987217       0.987169       0.987158
# 75%         0.990700       0.989963       0.989582       0.989415
# max         0.995340       0.993178       0.993387       0.993583
#
#        P4_closed_rsq  Pz_closed_rsq  T3_closed_rsq  T4_closed_rsq  \
# count      82.000000      82.000000      82.000000      82.000000
# mean        0.983367       0.982899       0.972333       0.972581
# std         0.013111       0.014637       0.039060       0.036834
# min         0.901453       0.887350       0.711227       0.717323
# 25%         0.981457       0.983409       0.976075       0.974488
# 50%         0.987227       0.986366       0.983331       0.983969
# 75%         0.990129       0.989480       0.986796       0.988018
# max         0.993438       0.993432       0.993000       0.993657
#
#        T5_closed_rsq  T6_closed_rsq
# count      82.000000      82.000000
# mean        0.978341       0.978149
# std         0.021788       0.022493
# min         0.855754       0.843863
# 25%         0.977256       0.978866
# 50%         0.985036       0.986024
# 75%         0.988743       0.988318
# max         0.992983       0.994066
#
# [8 rows x 38 columns]

# %%
channels = list(np.unique([col.split('_')[0] for col in our_rsq_df.columns]))

rmse_wilcoxon_pvals = np.empty((len(channels), 2))
rmse_ttest_pvals = np.empty((len(channels), 2))
rsq_wilcoxon_pvals = np.empty((len(channels), 2))
rsq_ttest_pvals = np.empty((len(channels), 2))
for cdx, channel in enumerate(channels):
    for sdx, state in enumerate(['open', 'closed']):
        rmse_fooof = fooof_rmse_df[[col for col in fooof_rmse_df.columns if channel in col and state in col]].mean(axis=1)
        rmse_our = our_rmse_df[[col for col in our_rmse_df.columns if channel in col and state in col]].mean(axis=1)
        rsq_fooof = fooof_rsq_df[[col for col in fooof_rsq_df.columns if channel in col and state in col]].mean(axis=1)
        rsq_our = our_rsq_df[[col for col in our_rsq_df.columns if channel in col and state in col]].mean(axis=1)
        rmse_wilcoxon_pvals[cdx, sdx] = wilcoxon(rmse_fooof, rmse_our, alternative='greater').pvalue
        rmse_ttest_pvals[cdx, sdx] = ttest_rel(rmse_fooof, rmse_our, alternative='greater').pvalue
        rsq_wilcoxon_pvals[cdx, sdx] = wilcoxon(rsq_fooof, rsq_our, alternative='less').pvalue
        rsq_ttest_pvals[cdx, sdx] = ttest_rel(rsq_fooof, rsq_our, alternative='less').pvalue

print(f"Min and max RMSE Wilcoxon p-values: {np.min(rmse_wilcoxon_pvals)} and {np.max(rmse_wilcoxon_pvals)}")
print(f"Min and max RMSE T-test p-values: {np.min(rmse_ttest_pvals)} and {np.max(rmse_ttest_pvals)}")
print(f"Min and max R-Squared Wilcoxon p-values: {np.min(rsq_wilcoxon_pvals)} and {np.max(rsq_wilcoxon_pvals)}")
print(f"Min and max R-Squared T-test p-values: {np.min(rsq_ttest_pvals)} and {np.max(rsq_ttest_pvals)}")


adjusted_rmse_wilcoxon_pvals = multipletests(rmse_wilcoxon_pvals.flatten(), method='holm')[1].reshape(rmse_wilcoxon_pvals.shape)
adjusted_rmse_ttest_pvals = multipletests(rmse_ttest_pvals.flatten(), method='holm')[1].reshape(rmse_ttest_pvals.shape)
adjusted_rsq_wilcoxon_pvals = multipletests(rsq_wilcoxon_pvals.flatten(), method='holm')[1].reshape(rsq_wilcoxon_pvals.shape)
adjusted_rsq_ttest_pvals = multipletests(rsq_ttest_pvals.flatten(), method='holm')[1].reshape(rsq_ttest_pvals.shape)

print(f"Adjusted Min and max RMSE Wilcoxon p-values: {np.min(adjusted_rmse_wilcoxon_pvals)} and {np.max(adjusted_rmse_wilcoxon_pvals)}")
print(f"Adjusted Min and max RMSE T-test p-values: {np.min(adjusted_rmse_ttest_pvals)} and {np.max(adjusted_rmse_ttest_pvals)}")
print(f"Adjusted Min and max R-Squared Wilcoxon p-values: {np.min(adjusted_rsq_wilcoxon_pvals)} and {np.max(adjusted_rsq_wilcoxon_pvals)}")
print(f"Adjusted Min and max R-Squared T-test p-values: {np.min(adjusted_rsq_ttest_pvals)} and {np.max(adjusted_rsq_ttest_pvals)}")
# Out:
# Min and max RMSE Wilcoxon p-values: nan and nan
# Min and max RMSE T-test p-values: nan and nan
# Min and max R-Squared Wilcoxon p-values: nan and nan
# Min and max R-Squared T-test p-values: nan and nan
# Adjusted Min and max RMSE Wilcoxon p-values: nan and nan
# Adjusted Min and max RMSE T-test p-values: nan and nan
# Adjusted Min and max R-Squared Wilcoxon p-values: nan and nan
# Adjusted Min and max R-Squared T-test p-values: nan and nan

# %%
all_wilcoxon_pval_df = pd.DataFrame(np.concatenate([rmse_wilcoxon_pvals, rsq_wilcoxon_pvals], axis=1), columns=['Open RMSE Wilcoxon', 'Closed RMSE Wilcoxon', 'Open R-Squared Wilcoxon', 'Closed R-Squared Wilcoxon'], index=channels)

all_ttest_pval_df = pd.DataFrame(np.concatenate([rmse_ttest_pvals, rsq_ttest_pvals], axis=1), columns=['Open RMSE T-test', 'Closed RMSE T-test', 'Open R-Squared T-test', 'Closed R-Squared T-test'], index=channels)
adjusted_all_wilcoxon_pval_df = pd.DataFrame(np.concatenate([adjusted_rmse_wilcoxon_pvals, adjusted_rsq_wilcoxon_pvals], axis=1), columns=['Open RMSE Holm-Bonferroni Adjusted Wilcoxon Signed Rank p-val', 'Closed RMSE Holm-Bonferroni Adjusted Wilcoxon Signed Rank p-val', 'Open R-Squared Holm-Bonferroni Adjusted Wilcoxon Signed Rank p-val', 'Closed R-Squared Holm-Bonferroni Adjusted Wilcoxon Signed Rank p-val'], index=channels)
adjusted_all_ttest_pval_df = pd.DataFrame(np.concatenate([adjusted_rmse_ttest_pvals, adjusted_rsq_ttest_pvals], axis=1), columns=['Open RMSE T-test', 'Closed RMSE T-test', 'Open R-Squared T-test', 'Closed R-Squared T-test'], index=channels)


adjusted_all_wilcoxon_pval_df
# Out:
#      Open RMSE Holm-Bonferroni Adjusted Wilcoxon Signed Rank p-val  \
# C3                                        2.203219e-10
# C4                                        1.702477e-11
# Cz                                        1.702477e-11
# F3                                        5.227719e-12
# F4                                        8.243703e-13
# F7                                        3.701863e-12
# F8                                        1.142514e-12
# Fp1                                       6.787068e-12
# Fp2                                       5.931333e-13
# Fz                                        2.101046e-12
# O1                                                 NaN
# O2                                        5.229442e-12
# P3                                        7.719713e-12
# P4                                        2.101046e-12
# Pz                                        1.341512e-11
# T3                                        2.522876e-12
# T4                                        1.471907e-12
# T5                                        8.967855e-10
# T6                                        6.594663e-12
#
#      Closed RMSE Holm-Bonferroni Adjusted Wilcoxon Signed Rank p-val  \
# C3                                        5.422122e-10
# C4                                        5.422122e-10
# Cz                                        2.449715e-07
# F3                                        1.886893e-11
# F4                                        4.172924e-10
# F7                                        1.369115e-11
# F8                                        2.414360e-10
# Fp1                                       1.702477e-11
# Fp2                                       2.617305e-10
# Fz                                        9.364300e-10
# O1                                        2.029748e-11
# O2                                        5.229442e-12
# P3                                        8.469773e-12
# P4                                        4.612540e-11
# Pz                                        2.248306e-09
# T3                                        5.582071e-12
# T4                                        2.029748e-11
# T5                                        2.142983e-11
# T6                                        1.886893e-11
#
#      Open R-Squared Holm-Bonferroni Adjusted Wilcoxon Signed Rank p-val  \
# C3                                        4.774959e-10
# C4                                        3.946954e-11
# Cz                                        5.698071e-11
# F3                                        8.716782e-12
# F4                                        3.062072e-12
# F7                                        3.807122e-12
# F8                                        3.821278e-12
# Fp1                                       8.716782e-12
# Fp2                                       7.345022e-13
# Fz                                        6.193888e-12
# O1                                                 NaN
# O2                                        8.716656e-12
# P3                                        8.716782e-12
# P4                                        2.741341e-12
# Pz                                        3.946954e-11
# T3                                        3.187975e-12
# T4                                        1.611591e-12
# T5                                        1.928924e-09
# T6                                        1.157245e-11
#
#      Closed R-Squared Holm-Bonferroni Adjusted Wilcoxon Signed Rank p-val
# C3                                        5.725693e-09
# C4                                        2.674775e-09
# Cz                                        9.684087e-08
# F3                                        2.158459e-10
# F4                                        1.614214e-09
# F7                                        6.970055e-11
# F8                                        6.075453e-10
# Fp1                                       7.461992e-11
# Fp2                                       1.928924e-09
# Fz                                        4.710073e-09
# O1                                        2.138801e-11
# O2                                        9.849319e-12
# P3                                        1.311640e-11
# P4                                        9.952463e-11
# Pz                                        4.730000e-09
# T3                                        8.716782e-12
# T4                                        5.113349e-11
# T5                                        2.158459e-10
# T6                                        9.952463e-11

# %% [markdown]
# # let's also grab the mean values

# %%
print(f"Average RMSE: SpecParam {fooof_avgrmse.mean():.3f} ± {fooof_avgrmse.sem():.3f},  Our Method {our_avgrmse.mean():.3f} ± {our_avgrmse.sem():.3f}, wilcoxon p-value {avgrmse_pval}, t-test p-value {avgrmse_ttest.pvalue}")
print(f"Average R-Squared: SpecParam {fooof_avgrsq.mean():.3f} ± {fooof_avgrsq.sem():.3f},  Our Method {our_avgrsq.mean():.3f} ± {our_avgrsq.sem():.3f}, wilcoxon p-value {avgrsq_pval}, t-test p-value {avgrsq_ttest.pvalue}")
# Out:
# Average RMSE: SpecParam 0.102 ± 0.003,  Our Method 0.086 ± 0.003, wilcoxon p-value 5.3740878719829113e-14, t-test p-value 1.6322210344132912e-22
# Average R-Squared: SpecParam 0.970 ± 0.002,  Our Method 0.979 ± 0.002, wilcoxon p-value 1.7425728494314134e-13, t-test p-value 1.2063560294417978e-14

# %%
print(f"Eyes Open RMSE: SpecParam {open_fooof_armse.mean():.3f} ± {open_fooof_armse.sem():.3f},  Our Method {open_our_armse.mean():.3f} ± {open_our_armse.sem():.3f}, wilcoxon p-value {open_wilcoxon.pvalue}, t-test p-value {open_ttest.pvalue}")
print(f"Eyes Closed RMSE: SpecParam {closed_fooof_armse.mean():.3f} ± {closed_fooof_armse.sem():.3f},  Our Method {closed_our_armse.mean():.3f} ± {closed_our_armse.sem():.3f}, wilcoxon p-value {closed_wilcoxon.pvalue}, t-test p-value {closed_ttest.pvalue}")

print(f"Eyes Open R-Squared: SpecParam {open_fooof_arsq.mean():.3f} ± {open_fooof_arsq.sem():.3f},  Our Method {open_our_arsq.mean():.3f} ± {open_our_arsq.sem():.3f}, wilcoxon p-value {open_wilcoxon_rsq.pvalue}, t-test p-value {open_ttest_rsq.pvalue}")
print(f"Eyes Closed R-Squared: SpecParam {closed_fooof_arsq.mean():.3f} ± {closed_fooof_arsq.sem():.3f},  Our Method {closed_our_arsq.mean():.3f} ± {closed_our_arsq.sem():.3f}, wilcoxon p-value {closed_wilcoxon_rsq.pvalue}, t-test p-value {closed_ttest_rsq.pvalue}")
# Out:
# Eyes Open RMSE: SpecParam 0.102 ± 0.003,  Our Method 0.083 ± 0.003, wilcoxon p-value 3.527545587598112e-14, t-test p-value 4.631253174028813e-17
# Eyes Closed RMSE: SpecParam 0.101 ± 0.003,  Our Method 0.089 ± 0.003, wilcoxon p-value 7.614837230612983e-14, t-test p-value 1.3574986521831847e-20
# Eyes Open R-Squared: SpecParam 0.968 ± 0.003,  Our Method 0.979 ± 0.003, wilcoxon p-value 3.527545587598112e-14, t-test p-value 4.113030090391417e-12
# Eyes Closed R-Squared: SpecParam 0.973 ± 0.003,  Our Method 0.979 ± 0.002, wilcoxon p-value 7.206519302620427e-13, t-test p-value 1.9114283692042988e-11

# %%
all_wilcoxon_pval_df
# Out:
#      Open RMSE Wilcoxon  Closed RMSE Wilcoxon  Open R-Squared Wilcoxon  \
# C3         2.002926e-11          8.741774e-11             4.340871e-11
# C4         8.800128e-13          7.745889e-11             1.942057e-12
# Cz         8.512384e-13          1.224858e-07             3.165595e-12
# F3         1.742573e-13          1.109937e-12             3.005787e-13
# F4         2.228028e-14          5.216155e-11             8.748778e-14
# F7         1.194149e-13          6.519598e-13             1.153673e-13
# F8         3.173651e-14          2.414360e-11             1.194149e-13
# Fp1        2.714827e-13          8.800128e-13             3.216547e-13
# Fp2        1.560877e-14          2.908116e-11             1.932900e-14
# Fz         6.179547e-14          2.341075e-10             1.998029e-13
# O1                  NaN          1.353165e-12                      NaN
# O2         1.803256e-13          1.866013e-13             2.905552e-13
# P3         3.216547e-13          3.682510e-13             3.109414e-13
# P4         6.179547e-14          3.843784e-12             7.614837e-14
# Pz         6.097784e-13          7.494355e-10             1.879502e-12
# T3         7.883989e-14          2.067434e-13             9.376397e-14
# T4         4.205450e-14          1.398495e-12             4.355651e-14
# T5         1.793571e-10          1.648448e-12             2.411155e-10
# T6         2.536409e-13          1.109937e-12             4.821856e-13
#
#      Closed R-Squared Wilcoxon
# C3                1.908564e-09
# C4                4.457959e-10
# Cz                4.842044e-08
# F3                1.660353e-11
# F4                1.793571e-10
# F7                4.100033e-12
# F8                6.075453e-11
# Fp1               4.663745e-12
# Fp2               2.483281e-10
# Fz                9.420145e-10
# O1                9.721821e-13
# O2                3.939728e-13
# P3                5.702783e-13
# P4                6.634975e-12
# Pz                1.182500e-09
# T3                3.216547e-13
# T4                2.691237e-12
# T5                1.660353e-11
# T6                6.850201e-12

# %%
all_rmse_means = np.empty((len(channels), 4))
all_rmse_sems = np.empty((len(channels), 4))
all_rsq_means = np.empty((len(channels), 4))
all_rsq_sems = np.empty((len(channels), 4))

for cdx, channel in enumerate(channels):
    for sdx, state in enumerate(['open', 'closed']):
        rmse_fooof = fooof_rmse_df[[col for col in fooof_rmse_df.columns if channel in col and state in col]].mean(axis=1)
        rmse_our = our_rmse_df[[col for col in our_rmse_df.columns if channel in col and state in col]].mean(axis=1)
        rsq_fooof = fooof_rsq_df[[col for col in fooof_rsq_df.columns if channel in col and state in col]].mean(axis=1)
        rsq_our = our_rsq_df[[col for col in our_rsq_df.columns if channel in col and state in col]].mean(axis=1)
        all_rmse_means[cdx, 2*sdx] = rmse_fooof.mean()
        all_rmse_means[cdx, 2*sdx+1] = rmse_our.mean()
        all_rmse_sems[cdx, 2*sdx] = rmse_fooof.sem()
        all_rmse_sems[cdx, 2*sdx+1] = rmse_our.sem()
        all_rsq_means[cdx, 2*sdx] = rsq_fooof.mean()
        all_rsq_means[cdx, 2*sdx+1] = rsq_our.mean()
        all_rsq_sems[cdx, 2*sdx] = rsq_fooof.sem()
        all_rsq_sems[cdx, 2*sdx+1] = rsq_our.sem()

all_rmse_means = pd.DataFrame(all_rmse_means, columns=['SpecParam Open RMSE', 'Our Method Open RMSE', 'SpecParam Closed RMSE', 'Our Method Closed RMSE'], index=channels)
all_rmse_sems = pd.DataFrame(all_rmse_sems, columns=['SpecParam Open RMSE SEM', 'Our Method Open RMSE SEM', 'SpecParam Closed RMSE SEM', 'Our Method Closed RMSE SEM'], index=channels)
all_rsq_means = pd.DataFrame(all_rsq_means, columns=['SpecParam Open R2', 'Our Method Open R2', 'SpecParam Closed R2', 'Our Method Closed R2'], index=channels)
all_rsq_sems = pd.DataFrame(all_rsq_sems, columns=['SpecParam Open R2 SEM', 'Our Method Open R2 SEM', 'SpecParam Closed R2 SEM', 'Our Method Closed R2 SEM'], index=channels)

all_rmse_vals = pd.concat([all_rmse_means, all_rmse_sems, adjusted_all_wilcoxon_pval_df[[col for col in adjusted_all_wilcoxon_pval_df.columns if 'RMSE' in col]], adjusted_all_ttest_pval_df[[col for col in adjusted_all_ttest_pval_df.columns if 'RMSE' in col]]], axis=1)
all_rsq_vals = pd.concat([all_rsq_means, all_rsq_sems, adjusted_all_wilcoxon_pval_df[[col for col in adjusted_all_wilcoxon_pval_df.columns if 'R-Squared' in col]], adjusted_all_ttest_pval_df[[col for col in adjusted_all_ttest_pval_df.columns if 'R-Squared' in col]]], axis=1)

all_error_results = pd.concat([all_rmse_vals, all_rsq_vals], axis=1)

all_error_results.to_csv('../data/tables/mission_connect_fit_analysis.csv')

# %%
all_error_results
# Out:
#      SpecParam Open RMSE  Our Method Open RMSE  SpecParam Closed RMSE  \
# C3              0.097582              0.086649               0.104131
# C4              0.095153              0.083184               0.097971
# Cz              0.090904              0.083507               0.094639
# F3              0.094129              0.076513               0.093828
# F4              0.103258              0.077236               0.094521
# F7              0.109140              0.080447               0.107457
# F8              0.109565              0.080374               0.110830
# Fp1             0.116778              0.078671               0.099251
# Fp2             0.114253              0.076479               0.097090
# Fz              0.088137              0.075104               0.092668
# O1              0.097999              0.085033               0.099844
# O2              0.098471              0.083975               0.099928
# P3              0.098976              0.089381               0.101693
# P4              0.101672              0.088325               0.100788
# Pz              0.100741              0.090817               0.108172
# T3              0.112266              0.081911               0.106781
# T4              0.117521              0.082322               0.107803
# T5              0.096236              0.084179               0.101700
# T6              0.099157              0.083934               0.100024
#
#      Our Method Closed RMSE  SpecParam Open RMSE SEM  \
# C3                 0.092105                 0.003540
# C4                 0.087210                 0.003597
# Cz                 0.089900                 0.002433
# F3                 0.083357                 0.003397
# F4                 0.084021                 0.004288
# F7                 0.088050                 0.005522
# F8                 0.091920                 0.004770
# Fp1                0.082806                 0.005091
# Fp2                0.082698                 0.004989
# Fz                 0.085271                 0.002392
# O1                 0.088940                 0.002691
# O2                 0.089042                 0.003467
# P3                 0.091930                 0.002884
# P4                 0.091186                 0.004165
# P4              0.979869              0.983367               0.004837
# Pz              0.980528              0.982899               0.001793
# T3              0.961119              0.972333               0.004691
# T4              0.960794              0.972581               0.006017
# T5              0.971172              0.978341               0.003512
# T6              0.972494              0.978149               0.005377
#
#      Our Method Open R2 SEM  SpecParam Closed R2 SEM  \
# C3                 0.003186                 0.003606
# C4                 0.006095                 0.003819
# Cz                 0.001722                 0.000878
# F3                 0.002373                 0.003484
# F4                 0.003016                 0.002808
# F7                 0.002543                 0.005848
# F8                 0.002283                 0.005496
# Fp1                0.002199                 0.004551
# Fp2                0.002478                 0.004133
# Fz                 0.001223                 0.001634
# O1                 0.002213                 0.001040
# O2                 0.003158                 0.001077
# P3                 0.002977                 0.001311
# P4                 0.004711                 0.001572
# Pz                 0.001886                 0.001434
# T3                 0.003025                 0.005072
# T4                 0.004537                 0.005266
# T5                 0.002941                 0.003028
# T6                 0.005181                 0.002628
#
#      Our Method Closed R2 SEM  \
# C3                   0.003475
# C4                   0.003560
# Cz                   0.000807
# F3                   0.003543
# F4                   0.002542
# F7                   0.003966
# F8                   0.004177
# Fp1                  0.003985
# Fp2                  0.003249
# Fz                   0.001667
# O1                   0.000816
# O2                   0.000917
# P3                   0.001141
# P4                   0.001448
# Pz                   0.001616
# T3                   0.004313
# T4                   0.004068
# T5                   0.002406
# T6                   0.002484
#
#      Open R-Squared Holm-Bonferroni Adjusted Wilcoxon Signed Rank p-val  \
# C3                                        4.774959e-10
# C4                                        3.946954e-11
# Cz                                        5.698071e-11
# F3                                        8.716782e-12
# F4                                        3.062072e-12
# F7                                        3.807122e-12
# F8                                        3.821278e-12
# Fp1                                       8.716782e-12
# Fp2                                       7.345022e-13
# Fz                                        6.193888e-12
# O1                                                 NaN
# O2                                        8.716656e-12
# P3                                        8.716782e-12
# P4                                        2.741341e-12
# Pz                                        3.946954e-11
# T3                                        3.187975e-12
# T4                                        1.611591e-12
# T5                                        1.928924e-09
# T6                                        1.157245e-11
#
#      Closed R-Squared Holm-Bonferroni Adjusted Wilcoxon Signed Rank p-val  \
# C3                                        5.725693e-09
# C4                                        2.674775e-09
# Cz                                        9.684087e-08
# F3                                        2.158459e-10
# F4                                        1.614214e-09
# F7                                        6.970055e-11
# F8                                        6.075453e-10
# Fp1                                       7.461992e-11
# Fp2                                       1.928924e-09
# Fz                                        4.710073e-09
# O1                                        2.138801e-11
# O2                                        9.849319e-12
# P3                                        1.311640e-11
# P4                                        9.952463e-11
# Pz                                        4.730000e-09
# T3                                        8.716782e-12
# T4                                        5.113349e-11
# T5                                        2.158459e-10
# T6                                        9.952463e-11
#
#      Open R-Squared T-test  Closed R-Squared T-test
# C3            8.803438e-03             4.075733e-05
# C4            1.653328e-07             2.115523e-03
# Cz            1.597202e-01             1.476282e-03
# F3            6.928082e-10             3.641736e-08
# F4            4.061498e-09             3.716426e-05
# F7            6.480563e-07             2.115523e-03
# F8            6.307718e-09             1.777139e-05
# Fp1           5.355543e-09             6.674857e-05
# Fp2           7.628596e-11             6.674857e-05
# Fz            4.001585e-08             1.931478e-06
# O1                     NaN             3.254832e-11
# O2            2.206330e-03             2.275006e-11
# P3            1.763812e-01             1.849325e-09
# P4            2.152164e-02             1.752642e-05
# Pz            1.786258e-10             4.392686e-03
# T3            8.124828e-08             1.777139e-05
# T4            8.789044e-10             1.961940e-06
# T5            7.348700e-03             2.909189e-03
# T6            6.891417e-04             9.938588e-07
#
# [19 rows x 24 columns]

# %% [markdown]
# # now we go by frequency

# %%
all_parameterized_spectra = out_dict['all_parameterized_spectra']
all_fooof_parameterized_spectra = out_dict['all_fooof_parameterized_spectra']
our_fitted_spectra = out_dict['our_fitted_spectra']
fooof_fitted_spectra = out_dict['fooof_fitted_spectra']

# %%
our_fitted_spectra[list(all_train_subjs)[0]]['open']['C3']
# Out:
# {'original': array([ 2.48859764,  2.61345537,  2.6767764 , ..., -1.0262611 ,
#         -1.03044144, -1.32897303]),
#  'modeled_spectrum': array([ 1.95155507,  2.5731309 ,  2.88627026, ..., -1.30084878,
#         -1.30180143, -1.30275368]),
#  'aperiodic_spectrum': array([ 0.34055436,  0.34055436,  0.34055436, ..., -1.3276572 ,
#         -1.32855764, -1.32945775]),
#  'peak_spectrum': array([1.61100071, 2.23257654, 2.5457159 , ..., 0.02680842, 0.0267562 ,
#         0.02670407]),
#  'freqs': array([  0.3,   0.4,   0.5, ..., 249.8, 249.9, 250. ])}

# %%
max_freqs = [1.5, 4, 8, 12.5, 30, 70, 150, 250]
all_train_subjs = list(all_parameterized_spectra.keys())


all_freq_rmse = np.ones((len(all_train_subjs), len(max_freqs), len(channels)*2, 2))*-1000 # subjs, max freqs, channels *  open/closed, us/foooof
all_freq_rsq = np.ones((len(all_train_subjs), len(max_freqs), len(channels)*2, 2))*-1000# subjs, max freqs, channels *  open/closed, us/foooof
ap_freq_rmse = np.ones((len(all_train_subjs), len(max_freqs), len(channels)*2, 2))*-1000
ap_freq_rsq = np.ones((len(all_train_subjs), len(max_freqs), len(channels)*2, 2))*-1000
gaussian_rmse = np.ones((len(all_train_subjs),  len(max_freqs),len(channels)*2, 2))*-1000
gaussian_rsq = np.ones((len(all_train_subjs),  len(max_freqs), len(channels)*2, 2))*-1000

# fill all with nans
all_freq_rmse.fill(np.nan)
all_freq_rsq.fill(np.nan)
ap_freq_rmse.fill(np.nan)
ap_freq_rsq.fill(np.nan)
gaussian_rmse.fill(np.nan)
gaussian_rsq.fill(np.nan)


for subjdx, subj in enumerate(all_train_subjs):
    for sdx, state in enumerate(['open', 'closed']):
        for cdx, channel in enumerate(channels):
            our_fit_spectra = our_fitted_spectra[subj][state][channel]
            original_psd = our_fit_spectra['original']
            modeled_spectrum = our_fit_spectra['modeled_spectrum']
            ap_spec = our_fit_spectra['aperiodic_spectrum']
            peak_spec = our_fit_spectra['peak_spectrum']
            freqs = our_fit_spectra['freqs']

            their_fit_spectra = fooof_fitted_spectra[subj][state][channel]
            assert np.all(original_psd == their_fit_spectra['original'])
            their_modeled_spectrum = their_fit_spectra['modeled_spectrum']
            their_ap_spec = their_fit_spectra['aperiodic_spectrum']
            their_peak_spec = their_fit_spectra['peak_spectrum']
            if their_peak_spec is None:
                print(f"Subject {subj} {state} {channel} has NaN values in FOOOF fit")
                viz_subj = subj
                viz_state = state
                viz_channel = channel
                flag_nan = True
            else:
                flag_nan = False
            assert np.all(freqs == their_fit_spectra['freqs'])
            for fdx, max_freq in enumerate(max_freqs):
                freq_mask = freqs <= max_freq
                fdx_rmse = np.sqrt(np.mean((modeled_spectrum[freq_mask]-original_psd[freq_mask])**2))
                fdx_rsq = np.corrcoef(original_psd[freq_mask], modeled_spectrum[freq_mask])[0,1]**2 ## this is how FOOOF calculates R^2
                fdx_ap_rmse = np.sqrt(np.mean((ap_spec[freq_mask]-original_psd[freq_mask])**2))
                fdx_ap_rsq = np.corrcoef(original_psd[freq_mask], ap_spec[freq_mask])[0,1]**2
                our_non_ap = modeled_spectrum - ap_spec
               
                our_original_residual = original_psd - ap_spec

                fdx_gaussian_rmse = np.sqrt(np.mean((our_non_ap[freq_mask]-our_original_residual[freq_mask])**2))
                fdx_gaussian_rsq = np.corrcoef(our_non_ap[freq_mask], our_original_residual[freq_mask])[0,1]**2 
                all_freq_rmse[subjdx, fdx, cdx*2+sdx, 0] = fdx_rmse
                all_freq_rsq[subjdx, fdx, cdx*2+sdx, 0] = fdx_rsq
                ap_freq_rmse[subjdx, fdx, cdx*2+sdx, 0] = fdx_ap_rmse
                ap_freq_rsq[subjdx, fdx, cdx*2+sdx, 0] = fdx_ap_rsq
                gaussian_rmse[subjdx, fdx, cdx*2+sdx, 0] = fdx_gaussian_rmse
                gaussian_rsq[subjdx, fdx, cdx*2+sdx, 0] = fdx_gaussian_rsq
                gaussian_rmse[subjdx, fdx, cdx*2+sdx, 0] = fdx_gaussian_rmse
                gaussian_rsq[subjdx, fdx, cdx*2+sdx, 0] = fdx_gaussian_rsq

                if flag_nan:
                    continue
                else:
                    fooof_fdx_rmse = np.sqrt(np.mean((their_modeled_spectrum[freq_mask]-original_psd[freq_mask])**2))
                    fooof_fdx_rsq = np.corrcoef(original_psd[freq_mask], their_modeled_spectrum[freq_mask])[0,1]**2


                    fooof_fdx_ap_rmse = np.sqrt(np.mean((their_ap_spec[freq_mask]-original_psd[freq_mask])**2))
                    fooof_fdx_ap_rsq = np.corrcoef(original_psd[freq_mask], their_ap_spec[freq_mask])[0,1]**2
                    fooof_non_ap = their_modeled_spectrum - their_ap_spec


                    fooof_original_residual = original_psd - their_ap_spec

                
                    fooof_fdx_gaussian_rmse = np.sqrt(np.mean((fooof_non_ap[freq_mask]-fooof_original_residual[freq_mask])**2))
                    fooof_fdx_gaussian_rsq = np.corrcoef(fooof_non_ap[freq_mask], fooof_original_residual[freq_mask])[0,1]**2

                    all_freq_rsq[subjdx, fdx, cdx*2+sdx, 1] = fooof_fdx_rsq
                    ap_freq_rmse[subjdx, fdx, cdx*2+sdx, 1] = fooof_fdx_ap_rmse
                    ap_freq_rsq[subjdx, fdx, cdx*2+sdx, 1] = fooof_fdx_ap_rsq
                    gaussian_rmse[subjdx, fdx, cdx*2+sdx, 1] = fooof_fdx_gaussian_rmse
                    all_freq_rmse[subjdx, fdx, cdx*2+sdx, 1] = fooof_fdx_rmse
                    gaussian_rsq[subjdx, fdx, cdx*2+sdx, 1] = fooof_fdx_gaussian_rsq


print(f"Missed filling in {np.sum(all_rmse_means == -1000)} rmse values")
print(f"Missed filling in {np.sum(all_rsq_means == -1000)} rsq values")

all_freq_rmse_means = np.nanmean(all_freq_rmse)
all_freq_rmse_sems = np.nanstd(all_freq_rmse)/np.sqrt(len(all_freq_rmse.flatten()))
all_freq_rsq_means = np.nanmean(all_freq_rsq)
all_freq_rsq_sems = np.nanstd(all_freq_rsq)/np.sqrt(len(all_freq_rsq.flatten()))

print(f"Average RMSE: {all_freq_rmse_means:.3f} ± {all_freq_rmse_sems:.3f}")
print(f"Average R-Squared: {all_freq_rsq_means:.3f} ± {all_freq_rsq_sems:.3f}")
for fdx, max_freq in enumerate(max_freqs):
    print(f"Average  RMSE up to {max_freq}: {np.nanmean(all_freq_rmse[:, fdx, ...]):.3f} ± {np.nanstd(all_freq_rmse[:, fdx, ...])/np.sqrt(len(all_freq_rmse[:, fdx, ...].flatten())):.3f}")
    print(f"Average  R-Squared up to {max_freq}: {np.nanmean(all_freq_rsq[:, fdx, ...]):.3f} ± {np.nanstd(all_freq_rsq[:, fdx, ...])/np.sqrt(len(all_freq_rsq[:, fdx, ...].flatten())):.3f}")
# Out:
# Subject 67 open O1 has NaN values in FOOOF fit
# Missed filling in SpecParam Open RMSE       0
# Our Method Open RMSE      0
# SpecParam Closed RMSE     0
# Our Method Closed RMSE    0
# dtype: int64 rmse values
# Missed filling in SpecParam Open R2       0
# Our Method Open R2      0
# SpecParam Closed R2     0
# Our Method Closed R2    0
# dtype: int64 rsq values
# Average RMSE: 0.154 ± 0.001
# Average R-Squared: 0.873 ± 0.001
# Average  RMSE up to 1.5: 0.283 ± 0.004
# Average  R-Squared up to 1.5: 0.778 ± 0.003
# Average  RMSE up to 4: 0.205 ± 0.003
# Average  R-Squared up to 4: 0.873 ± 0.002
# Average  RMSE up to 8: 0.167 ± 0.002
# Average  R-Squared up to 8: 0.840 ± 0.003
# Average  RMSE up to 12.5: 0.151 ± 0.002
# Average  R-Squared up to 12.5: 0.832 ± 0.003
# Average  RMSE up to 30: 0.127 ± 0.001
# Average  R-Squared up to 30: 0.862 ± 0.003
# Average  RMSE up to 70: 0.108 ± 0.001
# Average  R-Squared up to 70: 0.884 ± 0.002
# Average  RMSE up to 150: 0.096 ± 0.000
# Average  R-Squared up to 150: 0.940 ± 0.001
# Average  RMSE up to 250: 0.094 ± 0.000
# Average  R-Squared up to 250: 0.975 ± 0.000

# %%
our_freq_dfs = []
fooof_freq_dfs = []
our_ap_dfs = []
fooof_ap_dfs = []
our_gaussian_dfs = []
fooof_gaussian_dfs = []
for fdx, max_freq in enumerate(max_freqs):
    our_freq_rmse_df = pd.DataFrame(all_freq_rmse[:, fdx, :, 0], columns=[f'BandParam_{max_freq}_{channel}_{state}_RMSE' for state in ['open', 'closed'] for channel in channels], index=all_train_subjs)
    fooof_freq_rmse_df = pd.DataFrame(all_freq_rmse[:, fdx, :, 1], columns=[f'FOOOF_{max_freq}_{channel}_{state}_RMSE' for state in ['open', 'closed'] for channel in channels], index=all_train_subjs)
    our_freq_rsq_df = pd.DataFrame(all_freq_rsq[:, fdx, :, 0], columns=[f'BandParam_{max_freq}_{channel}_{state}_R-Squared' for state in ['open', 'closed'] for channel in channels], index=all_train_subjs)
    fooof_freq_rsq_df = pd.DataFrame(all_freq_rsq[:, fdx, :, 1], columns=[f'FOOOF_{max_freq}_{channel}_{state}_R-Squared' for state in ['open', 'closed'] for channel in channels], index=all_train_subjs)
    our_freq_dfs.append(our_freq_rmse_df)
    fooof_freq_dfs.append(fooof_freq_rmse_df)
    our_freq_dfs.append(our_freq_rsq_df)
    fooof_freq_dfs.append(fooof_freq_rsq_df)

    our_ap_rmse_df = pd.DataFrame(ap_freq_rmse[:, fdx, :, 0], columns=[f'BandParam_{max_freq}_{channel}_{state}_RMSE' for state in ['open', 'closed'] for channel in channels], index=all_train_subjs)
    fooof_ap_rmse_df = pd.DataFrame(ap_freq_rmse[:, fdx, :, 1], columns=[f'FOOOF_{max_freq}_{channel}_{state}_RMSE' for state in ['open', 'closed'] for channel in channels], index=all_train_subjs)
    our_ap_rsq_df = pd.DataFrame(ap_freq_rsq[:, fdx, :, 0], columns=[f'BandParam_{max_freq}_{channel}_{state}_R-Squared' for state in ['open', 'closed'] for channel in channels], index=all_train_subjs)
    fooof_ap_rsq_df = pd.DataFrame(ap_freq_rsq[:, fdx, :, 1], columns=[f'FOOOF_{max_freq}_{channel}_{state}_R-Squared' for state in ['open', 'closed'] for channel in channels], index=all_train_subjs)
    our_ap_dfs.append(our_ap_rmse_df)
    fooof_ap_dfs.append(fooof_ap_rmse_df)
    our_ap_dfs.append(our_ap_rsq_df)
    fooof_ap_dfs.append(fooof_ap_rsq_df)

    our_gaussian_rmse_df = pd.DataFrame(gaussian_rmse[:, fdx, :, 0], columns=[f'BandParam_{channel}_{state}_RMSE' for state in ['open', 'closed'] for channel in channels], index=all_train_subjs)
    fooof_gaussian_rmse_df = pd.DataFrame(gaussian_rmse[:, fdx, :, 1], columns=[f'FOOOF_{channel}_{state}_RMSE' for state in ['open', 'closed'] for channel in channels], index=all_train_subjs)
    our_gaussian_rsq_df = pd.DataFrame(gaussian_rsq[:, fdx,:, 0], columns=[f'BandParam_{channel}_{state}_R-Squared' for state in ['open', 'closed'] for channel in channels], index=all_train_subjs)
    fooof_gaussian_rsq_df = pd.DataFrame(gaussian_rsq[:,fdx, :, 1], columns=[f'FOOOF_{channel}_{state}_R-Squared' for state in ['open', 'closed'] for channel in channels], index=all_train_subjs)
    our_gaussian_dfs.append(our_gaussian_rmse_df)
    fooof_gaussian_dfs.append(fooof_gaussian_rmse_df)
    our_gaussian_dfs.append(our_gaussian_rsq_df)
    fooof_gaussian_dfs.append(fooof_gaussian_rsq_df)


our_freq_df = pd.concat(our_freq_dfs, axis=1)
fooof_freq_df = pd.concat(fooof_freq_dfs, axis=1)

# %% [markdown]
# # band by band

# %%
standard_bands = [(0.3, 1.5), (1.5, 4), (4, 8), (8, 12.5), (12.5, 30), (30, 70), (70, 150)]


band_rmse = np.ones((len(all_train_subjs), len(standard_bands), len(channels)*2, 2))
band_rsq = np.ones((len(all_train_subjs), len(standard_bands), len(channels)*2, 2))
band_rmse.fill(np.nan)
band_rsq.fill(np.nan)

# %%
our_freq_df
# Out:
#      BandParam_1.5_C3_open_RMSE  BandParam_1.5_C4_open_RMSE  \
# 66                     0.209297                    0.123312
# 31                     0.056598                    0.135370
# 154                    0.046015                    0.058251
# 65                     0.043431                    0.048540
# 64                     0.172359                    0.102353
# ..                          ...                         ...
# 176                    0.042264                    0.045212
# 90                     0.056332                    0.046191
# 122                    0.043668                    0.053556
# 72                     0.059988                    0.098954
# 27                     0.048428                    0.122124
#
#      BandParam_1.5_Cz_open_RMSE  BandParam_1.5_F3_open_RMSE  \
# 66                     0.063382                    0.083436
# 31                     0.086736                    0.104584
# 154                    0.052985                    0.088428
# 65                     0.056686                    0.053003
# 64                     0.172109                    0.095398
# ..                          ...                         ...
# 176                    0.116759                    0.110476
# 90                     0.088038                    0.042017
# 122                    0.067370                    0.023400
# 72                     0.069975                    0.033935
# 27                     0.031430                    0.045381
#
#      BandParam_1.5_F4_open_RMSE  BandParam_1.5_F7_open_RMSE  \
# 66                     0.093846                    0.117522
# 31                     0.076106                    0.080038
# 154                    0.088681                    0.047043
# 65                     0.048852                    0.075420
# 64                     0.055516                    0.074638
# ..                          ...                         ...
# 176                    0.077993                    0.037416
# 90                     0.083190                    0.055184
# 122                    0.049555                    0.038542
# 72                     0.056983                    0.026560
# 27                     0.103332                    0.049220
#
#      BandParam_1.5_F8_open_RMSE  BandParam_1.5_Fp1_open_RMSE  \
# 66                     0.117768                     0.114115
# 31                     0.135921                     0.053335
# 154                    0.041410                     0.042867
# 65                     0.146846                     0.040576
# 64                     0.123425                     0.216070
# ..                          ...                          ...
# 176                    0.072762                     0.092272
# 90                     0.067249                     0.099314
# 122                    0.040037                     0.056751
# 72                     0.162606                     0.263191
# 27                     0.060585                     0.053449
#
#      BandParam_1.5_Fp2_open_RMSE  BandParam_1.5_Fz_open_RMSE  ...  \
# 66                      0.259376                    0.227773  ...
# 31                      0.054723                    0.204616  ...
# 154                     0.068263                    0.041084  ...
# 65                      0.235135                    0.210095  ...
# 64                      0.144933                    0.291172  ...
# ..                           ...                         ...  ...
# 176                     0.077327                    0.060739  ...
# 90                      0.092216                    0.064102  ...
# 122                     0.031957                    0.032276  ...
# 72                      0.130910                    0.054704  ...
# 27                      0.065986                    0.058626  ...
#
#      BandParam_250_Fz_closed_R-Squared  BandParam_250_O1_closed_R-Squared  \
# 66                            0.978375                           0.971836
# 31                            0.966635                           0.988539
# 154                           0.989147                           0.986718
# 65                            0.984880                           0.989197
# 64                            0.953073                           0.967708
# ..                                 ...                                ...
# 176                           0.985101                           0.977903
# 90                            0.986694                           0.988659
# 122                           0.991006                           0.989797
# 72                            0.988924                           0.989421
# 27                            0.986902                           0.986338
#
#      BandParam_250_O2_closed_R-Squared  BandParam_250_P3_closed_R-Squared  \
# 66                            0.979387                           0.968742
# 31                            0.949466                           0.985703
# 154                           0.982096                           0.983628
# 65                            0.979673                           0.984262
# 64                            0.899586                           0.951576
# ..                                 ...                                ...
# 176                           0.987438                           0.973610
# 90                            0.984826                           0.982888
# 122                           0.990416                           0.989681
# 72                            0.985819                           0.975973
# 27                            0.987952                           0.988057
#
#      BandParam_250_P4_closed_R-Squared  BandParam_250_Pz_closed_R-Squared  \
# 66                            0.935533                           0.921884
# 31                            0.953186                           0.977787
# 154                           0.984236                           0.985042
# 65                            0.972863                           0.979011
# 64                            0.961926                           0.970151
# ..                                 ...                                ...
# 176                           0.983638                           0.973620
# 90                            0.986780                           0.987012
# 122                           0.990525                           0.989926
# 72                            0.981710                           0.982622
# 27                            0.986982                           0.986975
#
#      BandParam_250_T3_closed_R-Squared  BandParam_250_T4_closed_R-Squared  \
# 66                            0.978028                           0.969085
# 31                            0.960614                           0.988674
# 154                           0.984459                           0.985062
# 65                            0.974048                           0.984593
# 64                            0.931592                           0.964158
# ..                                 ...                                ...
# 176                           0.982494                           0.973009
# 90                            0.983469                           0.987191
# 122                           0.992541                           0.992114
# 72                            0.988092                           0.985651
# 27                            0.985782                           0.985011
#
#      BandParam_250_T5_closed_R-Squared  BandParam_250_T6_closed_R-Squared
# 66                            0.959938                           0.943822
# 31                            0.958186                           0.988179
# 154                           0.983726                           0.984579
# 65                            0.979467                           0.987362
# 64                            0.970661                           0.973436
# ..                                 ...                                ...
# 176                           0.981786                           0.974530
# 90                            0.983953                           0.986042
# 122                           0.991881                           0.991472
# 72                            0.984971                           0.989233
# 27                            0.984455                           0.984490
#
# [82 rows x 608 columns]

# %%
fooof_freq_df
# Out:
#      FOOOF_1.5_C3_open_RMSE  FOOOF_1.5_C4_open_RMSE  FOOOF_1.5_Cz_open_RMSE  \
# 66                 0.251113                0.498249                0.939085
# 31                 0.328230                0.392815                1.094810
# 154                0.445050                0.052663                0.855276
# 65                 0.249387                0.307778                0.271245
# 64                 0.131482                1.500242                0.093415
# ..                      ...                     ...                     ...
# 176                0.417289                0.219378                0.194518
# 90                 0.675846                0.416674                0.797193
# 122                0.454483                0.613389                0.515575
# 72                 0.250127                0.186132                0.362124
# 27                 0.053496                0.746995                0.578706
#
#      FOOOF_1.5_F3_open_RMSE  FOOOF_1.5_F4_open_RMSE  FOOOF_1.5_F7_open_RMSE  \
# 66                 1.096336                0.320256                0.624434
# 31                 0.199212                0.359025                0.275390
# 154                0.218415                0.967236                0.129695
# 65                 0.479859                0.219026                0.259042
# 64                 0.653673                0.208273                0.229315
# ..                      ...                     ...                     ...
# 176                0.146447                0.234381                0.316570
# 90                 0.468860                0.190912                0.226522
# 122                0.433379                0.103586                0.227590
# 72                 0.165723                0.195427                0.172227
# 27                 0.633118                0.252544                0.329342
#
#      FOOOF_1.5_F8_open_RMSE  FOOOF_1.5_Fp1_open_RMSE  FOOOF_1.5_Fp2_open_RMSE  \
# 66                 0.335915                 0.730903                 1.457302
# 31                 0.302031                 0.209687                 0.755882
# 154                0.659765                 0.671770                 0.934019
# 65                 0.418216                 0.369150                 0.133424
# 64                 0.998867                 0.599730                 0.528323
# ..                      ...                      ...                      ...
# 176                0.393793                 0.453946                 0.432384
# 90                 0.774595                 0.099173                 0.958462
# 122                0.290235                 0.156050                 0.508620
# 72                 0.206307                 0.239838                 1.030530
# 27                 0.740169                 0.805246                 0.092085
#
#      FOOOF_1.5_Fz_open_RMSE  ...  FOOOF_250_Fz_closed_R-Squared  \
# 66                 1.791673  ...                       0.971437
# 31                 0.289423  ...                       0.956574
# 154                0.749201  ...                       0.988144
# 65                 0.379306  ...                       0.985134
# 64                 0.617485  ...                       0.950773
# ..                      ...  ...                            ...
# 176                0.409732  ...                       0.982491
# 90                 0.112483  ...                       0.977571
# 122                0.437306  ...                       0.991595
# 72                 0.322187  ...                       0.986300
# 27                 0.366122  ...                       0.980475
#
#      FOOOF_250_O1_closed_R-Squared  FOOOF_250_O2_closed_R-Squared  \
# 66                        0.957587                       0.819997
# 31                        0.986255                       0.858813
# 154                       0.984148                       0.912427
# 65                        0.986818                       0.978378
# 64                        0.967281                       0.836051
# ..                             ...                            ...
# 176                       0.976615                       0.955290
# 90                        0.984167                       0.945048
# 122                       0.990582                       0.989885
# 72                        0.987345                       0.978237
# 27                        0.985333                       0.964189
#
#      FOOOF_250_P3_closed_R-Squared  FOOOF_250_P4_closed_R-Squared  \
# 66                        0.813576                       0.850823
# 31                        0.975720                       0.883184
# 154                       0.954801                       0.955676
# 65                        0.976561                       0.974524
# 64                        0.942430                       0.959500
# ..                             ...                            ...
# 176                       0.967305                       0.946832
# 90                        0.974180                       0.956072
# 122                       0.982989                       0.987813
# 72                        0.974063                       0.959593
# 27                        0.969979                       0.975395
#
#      FOOOF_250_Pz_closed_R-Squared  FOOOF_250_T3_closed_R-Squared  \
# 66                        0.819070                       0.971805
# 31                        0.958032                       0.963215
# 154                       0.969441                       0.978545
# 65                        0.984105                       0.962906
# 64                        0.966599                       0.887806
# ..                             ...                            ...
# 176                       0.969797                       0.979809
# 90                        0.972246                       0.965359
# 122                       0.989113                       0.988687
# 72                        0.980140                       0.986364
# 27                        0.971035                       0.976634
#
#      FOOOF_250_T4_closed_R-Squared  FOOOF_250_T5_closed_R-Squared  \
# 66                        0.817051                       0.910253
# 31                        0.984181                       0.966555
# 154                       0.986283                       0.966811
# 65                        0.975639                       0.975576
# 64                        0.959602                       0.967259
# ..                             ...                            ...
# 176                       0.972065                       0.976463
# 90                        0.987059                       0.966379
# 122                       0.988540                       0.989529
# 72                        0.984600                       0.981139
# 27                        0.970116                       0.978559
#
#      FOOOF_250_T6_closed_R-Squared
# 66                        0.893439
# 31                        0.985972
# 154                       0.985562
# 65                        0.983848
# 64                        0.970817
# ..                             ...
# 176                       0.969891
# 90                        0.985414
# 122                       0.988574
# 72                        0.987713
# 27                        0.975549
#
# [82 rows x 608 columns]

# %% [markdown]
# ## let's plot the average rmse over the frequencies and then the average rsq over the frequencies and get the p-values

# %%
import scipy.stats as stats
our_rmse_freqmeans = np.nanmean(all_freq_rmse[..., 0], axis=(0, 2))
our_rmse_freqstds = np.nanstd(all_freq_rmse[..., 0], axis=(0, 2))
fooof_rmse_freqmeans = np.nanmean(all_freq_rmse[..., 1], axis=(0, 2))
fooof_rmse_freqstds = np.nanstd(all_freq_rmse[..., 1], axis=(0, 2))
our_rsq_freqmeans = np.nanmean(all_freq_rsq[..., 0], axis=(0, 2))
our_rsq_freqstds = np.nanstd(all_freq_rsq[..., 0], axis=(0, 2))
fooof_rsq_freqmeans = np.nanmean(all_freq_rsq[..., 1], axis=(0, 2))
fooof_rsq_freqstds = np.nanstd(all_freq_rsq[..., 1], axis=(0, 2))

our_ap_freqmeans = np.nanmean(ap_freq_rmse[..., 0], axis=(0, 2))
our_ap_freqstds = np.nanstd(ap_freq_rmse[..., 0], axis=(0, 2))
fooof_ap_freqmeans = np.nanmean(ap_freq_rmse[..., 1], axis=(0, 2))
fooof_ap_freqstds = np.nanstd(ap_freq_rmse[..., 1], axis=(0, 2))
our_ap_rsqmeans = np.nanmean(ap_freq_rsq[..., 0], axis=(0, 2))
our_ap_rsqsems = np.nanstd(ap_freq_rsq[..., 0], axis=(0, 2))
fooof_ap_rsqmeans = np.nanmean(ap_freq_rsq[..., 1], axis=(0, 2))
fooof_ap_rsqsems = np.nanstd(ap_freq_rsq[..., 1], axis=(0, 2))
our_gaussian_rmse_means = np.nanmean(gaussian_rmse[..., 0], axis=(0, 2))
our_gaussian_rmse_sems = np.nanstd(gaussian_rmse[..., 0], axis=(0, 2))
fooof_gaussian_rmse_means = np.nanmean(gaussian_rmse[..., 1], axis=(0, 2))
fooof_gaussian_rmse_sems = np.nanstd(gaussian_rmse[..., 1], axis=(0, 2))
our_gaussian_rsq_means = np.nanmean(gaussian_rsq[..., 0], axis=(0, 2))
our_gaussian_rsq_sems = np.nanstd(gaussian_rsq[..., 0], axis=(0, 2))
fooof_gaussian_rsq_means = np.nanmean(gaussian_rsq[..., 1], axis=(0, 2))
fooof_gaussian_rsq_sems = np.nanstd(gaussian_rsq[..., 1], axis=(0, 2))


fig, axs = plt.subplots(1, 3, figsize=(12,4))
axs[0].errorbar(max_freqs, our_rmse_freqmeans, yerr=our_rmse_freqstds, label='Our Method', marker='o', linestyle='--')
axs[0].errorbar(max_freqs, fooof_rmse_freqmeans, yerr=fooof_rmse_freqstds, label='SpecParam', marker='o', linestyle='--')
axs[0].set_title('Average Total RMSE')
axs[0].set_xlabel('Max Frequency')
axs[0].set_ylabel('RMSE')
axs[0].legend()
axs[0].set_xscale('log')

axs[1].errorbar(max_freqs, our_ap_freqmeans, yerr=our_ap_freqstds, label='Our Method', marker='o', linestyle='--')
axs[1].errorbar(max_freqs, fooof_ap_freqmeans, yerr=fooof_ap_freqstds, label='SpecParam', marker='o', linestyle='--')
axs[1].set_title('Average Aperiodic RMSE')
axs[1].set_xlabel('Max Frequency')
axs[1].set_ylabel('RMSE')
axs[1].set_xscale('log')

axs[2].errorbar(max_freqs, our_gaussian_rmse_means, yerr=our_gaussian_rmse_sems, label='Our Method', marker='o', linestyle='--')
axs[2].errorbar(max_freqs, fooof_gaussian_rmse_means, yerr=fooof_gaussian_rmse_sems, label='SpecParam', marker='o', linestyle='--')
axs[2].set_title('Average Periodic RMSE')
axs[2].set_xlabel('Max Frequency')
axs[2].set_ylabel('RMSE')
axs[2].set_xscale('log')
plt.show()

# %%
fooof_ap_freqstds
# Out:
# array([0.52800029, 0.38165941, 0.27168823, 0.21276867, 0.13738998,
#        0.09246276, 0.09384266, 0.07907453])

# %%
freq_rmse_pvals = np.empty((len(max_freqs), 2))
freq_rsq_pvals = np.empty((len(max_freqs), 2))
freq_rmse_pvals.fill(np.nan)
freq_rsq_pvals.fill(np.nan)
for fdx, max_freq in enumerate(max_freqs):
    fooof_freq_rmse = np.mean(all_freq_rmse[:, fdx, :, 1], axis=-1)
    our_freq_rmse = np.mean(all_freq_rmse[:, fdx, :, 0], axis=-1)
    print(f"Shape of fooof and our RMSE: {fooof_freq_rmse.shape}, {our_freq_rmse.shape}")
    print(f"Number of fooof nan and non-nan: {np.sum(np.isnan(fooof_freq_rmse))}, {np.sum(~np.isnan(fooof_freq_rmse))}")
    print(f"Number of our nan and non-nan: {np.sum(np.isnan(our_freq_rmse))}, {np.sum(~np.isnan(our_freq_rmse))}")
    freq_rmse_pvals[fdx, 0] = wilcoxon(fooof_freq_rmse, our_freq_rmse, alternative='greater', nan_policy='omit').pvalue
    freq_rmse_pvals[fdx, 1] = ttest_rel(fooof_freq_rmse, our_freq_rmse, alternative='greater', nan_policy='omit').pvalue

    fooof_freq_rsq = np.mean(all_freq_rsq[:, fdx, :, 1], axis=-1)
    our_freq_rsq = np.mean(all_freq_rsq[:, fdx, :, 0], axis=-1)
    freq_rsq_pvals[fdx, 0] = wilcoxon(fooof_freq_rsq, our_freq_rsq, alternative='less', nan_policy='omit').pvalue
    freq_rsq_pvals[fdx, 1] = ttest_rel(fooof_freq_rsq, our_freq_rsq, alternative='less', nan_policy='omit').pvalue

print(f"Min and max RMSE Wilcoxon p-values: {np.min(freq_rmse_pvals[:, 0])} and {np.max(freq_rmse_pvals[:, 0])}")
print(f"Min and max RMSE T-test p-values: {np.min(freq_rmse_pvals[:, 1])} and {np.max(freq_rmse_pvals[:, 1])}")
print(f"Min and max R-Squared Wilcoxon p-values: {np.min(freq_rsq_pvals[:, 0])} and {np.max(freq_rsq_pvals[:, 0])}")
print(f"Min and max R-Squared T-test p-values: {np.min(freq_rsq_pvals[:, 1])} and {np.max(freq_rsq_pvals[:, 1])}")
# Out:
# Shape of fooof and our RMSE: (82,), (82,)
# Number of fooof nan and non-nan: 1, 81
# Number of our nan and non-nan: 0, 82
# Shape of fooof and our RMSE: (82,), (82,)
# Number of fooof nan and non-nan: 1, 81
# Number of our nan and non-nan: 0, 82
# Shape of fooof and our RMSE: (82,), (82,)
# Number of fooof nan and non-nan: 1, 81
# Number of our nan and non-nan: 0, 82
# Shape of fooof and our RMSE: (82,), (82,)
# Number of fooof nan and non-nan: 1, 81
# Number of our nan and non-nan: 0, 82
# Shape of fooof and our RMSE: (82,), (82,)
# Number of fooof nan and non-nan: 1, 81
# Number of our nan and non-nan: 0, 82
# Shape of fooof and our RMSE: (82,), (82,)
# Number of fooof nan and non-nan: 1, 81
# Number of our nan and non-nan: 0, 82
# Shape of fooof and our RMSE: (82,), (82,)
# Number of fooof nan and non-nan: 1, 81
# Number of our nan and non-nan: 0, 82
# Shape of fooof and our RMSE: (82,), (82,)
# Number of fooof nan and non-nan: 1, 81
# Number of our nan and non-nan: 0, 82
# Min and max RMSE Wilcoxon p-values: 2.6813131325564844e-15 and 7.900779557354363e-14
# Min and max RMSE T-test p-values: 1.7544904471166215e-42 and 4.746657717406757e-22
# Min and max R-Squared Wilcoxon p-values: 2.6813131325564844e-15 and 2.5965310852369714e-13
# Min and max R-Squared T-test p-values: 1.42228928688944e-47 and 2.750651013179465e-14

# %%
freq_rmse_pvals
# Out:
# array([[2.68131313e-15, 3.79446977e-39],
#        [2.68131313e-15, 1.80111922e-41],
#        [2.68131313e-15, 1.75449045e-42],
#        [2.68131313e-15, 2.06693710e-41],
#        [2.68131313e-15, 4.23360695e-40],
#        [2.68131313e-15, 4.85470878e-39],
#        [2.88940483e-15, 7.53041984e-33],
#        [7.90077956e-14, 4.74665772e-22]])

# %%
fig, axs = plt.subplots(1, 3, figsize=(12,4))

axs[0].errorbar(max_freqs, our_rsq_freqmeans, yerr=our_rsq_freqstds, label='Our Method', marker='o', linestyle='--')
axs[0].errorbar(max_freqs, fooof_rsq_freqmeans, yerr=fooof_rsq_freqstds, label='SpecParam', marker='o', linestyle='--')
axs[0].set_title('Average Total R-Squared')
axs[0].set_xlabel('Max Frequency')
axs[0].set_ylabel('R-Squared')
axs[0].legend()
axs[0].set_xscale('log')

axs[1].errorbar(max_freqs, our_ap_rsqmeans, yerr=our_ap_rsqsems, label='Our Method', marker='o', linestyle='--')
axs[1].errorbar(max_freqs, fooof_ap_rsqmeans, yerr=fooof_ap_rsqsems, label='SpecParam', marker='o', linestyle='--')
axs[1].set_title('Average Aperiodic R-Squared')
axs[1].set_xlabel('Max Frequency')
axs[1].set_ylabel('R-Squared')
axs[1].set_xscale('log')

axs[2].errorbar(max_freqs, our_gaussian_rsq_means, yerr=our_gaussian_rsq_sems, label='Our Method', marker='o', linestyle='--')
axs[2].errorbar(max_freqs, fooof_gaussian_rsq_means, yerr=fooof_gaussian_rsq_sems, label='SpecParam', marker='o', linestyle='--')
axs[2].set_title('Average Periodic R-Squared')
axs[2].set_xlabel('Max Frequency')
axs[2].set_ylabel('R-Squared')
axs[2].set_xscale('log')
plt.show()

# %% [markdown]
# # viz the two

# %%
subj = viz_subj
state = viz_state
print(f"PSD shape: {psd_dict[subj][state].data.shape}")
channels = psd_dict[subj][state].ch_names
channel = viz_channel
chdx = channels.index(channel)
psd, freqs = psd_dict[subj][state].get_data(return_freqs=True)
norm_psd = du.PSDScaler(normalize_method='median', channel_independence=False, normalize_a=None, normalize_b=None).fit_transform(psd)
processed_freqs, processed_psd = process_power_spectrum(freqs, np.mean(norm_psd, axis=0)[chdx])
standard_bands = [(0.3, 1.5), (1.5, 4), (4, 8), (8, 12.5), (12.5, 30), (30, 70), (70, 150)]

our_ap_params = all_parameterized_spectra[subj][state][channel]['aperiodic_params']
our_gaussian_params = all_parameterized_spectra[subj][state][channel]['gaussian_params']
our_spectrum, our_peak, our_ap = reconstruct_bandparam_spectrum(processed_freqs, our_ap_params, our_gaussian_params, standard_bands)

fooof_ap_params = all_fooof_parameterized_spectra[subj][state][channel]['aperiodic_params']
fooof_gaussian_params = all_fooof_parameterized_spectra[subj][state][channel]['peak_params']
fooof_spectrum, fooof_peak, fooof_ap = reconstruct_fooof_spectrum(processed_freqs, fooof_ap_params, fooof_gaussian_params)

fig, axs = plt.subplots(1,2, figsize=(12,4))
axs[0].plot(processed_freqs, np.log10(processed_psd), label='Original PSD')
axs[0].plot(freqs, fooof_spectrum, label='SpecParam')
axs[0].plot(freqs, fooof_peak, label='SpecParam Peaks')
axs[0].plot(freqs, fooof_ap, label='SpecParam Aperiodic')
axs[0].set_title('SpecParam')
axs[0].set_xlabel('Frequency (Hz)')
axs[0].set_ylabel('Power (dB)')
axs[0].legend()
axs[1].plot(processed_freqs, np.log10(processed_psd), label='Original PSD')
axs[1].plot(freqs, our_spectrum, label='Our Method')
axs[1].plot(freqs, our_peak, label='Our Peaks')
axs[1].plot(freqs, our_ap, label='Our Aperiodic')
axs[1].set_title('Our Method')
axs[1].set_xlabel('Frequency (Hz)')
axs[1].set_ylabel('Power (dB)')
axs[1].legend()
print(f"Subject: {subj}, State: {state}, Channel: {channel}")
plt.show()
# Out:
# PSD shape: (10, 19, 2498)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 9
#       7 psd, freqs = psd_dict[subj][state].get_data(return_freqs=True)
#       8 norm_psd = du.PSDScaler(normalize_method='median', channel_independence=False, normalize_a=None, normalize_b=None).fit_transform(psd)
# ----> 9 processed_freqs, processed_psd = process_power_spectrum(freqs, np.mean(norm_psd, axis=0)[chdx])
#      10 standard_bands = [(0.3, 1.5), (1.5, 4), (4, 8), (8, 12.5), (12.5, 30), (30, 70), (70, 150)]
#      12 our_ap_params = all_parameterized_spectra[subj][state][channel]['aperiodic_params']
#
# NameError: name 'process_power_spectrum' is not defined

# %%
fooof_gaussian_params
# Out:
# array([nan, nan, nan])

# %%
subj = np.random.choice(list(all_parameterized_spectra.keys()))
state = np.random.choice(['open', 'closed'])
print(f"PSD shape: {psd_dict[subj][state].data.shape}")
channels = psd_dict[subj][state].ch_names
channel = np.random.choice(channels)
chdx = channels.index(channel)
our_fit_spectra = our_fitted_spectra[subj][state][channel]
their_fit_spectra = fooof_fitted_spectra[subj][state][channel]
processed_freqs = our_fit_spectra['freqs']
processed_psd = our_fit_spectra['original']
their_processed_psd = their_fit_spectra['original']
standard_bands = [(0.3, 1.5), (1.5, 4), (4, 8), (8, 12.5), (12.5, 30), (30, 70), (70, 150)]

our_ap_params = all_parameterized_spectra[subj][state][channel]['aperiodic_params']
our_gaussian_params = all_parameterized_spectra[subj][state][channel]['gaussian_params']
our_spectrum, our_peak, our_ap = gpf.reconstruct_bandparam_spectrum(processed_freqs, our_ap_params, our_gaussian_params, standard_bands)

fooof_ap_params = all_fooof_parameterized_spectra[subj][state][channel]['aperiodic_params']
fooof_gaussian_params = all_fooof_parameterized_spectra[subj][state][channel]['peak_params']
fooof_spectrum, fooof_peak, fooof_ap = gpf.reconstruct_fooof_spectrum(processed_freqs, fooof_ap_params, fooof_gaussian_params)

for iii in range(2):
    fig, axs = plt.subplots(1,2, figsize=(12,4))
    axs[0].plot(processed_freqs, their_processed_psd, label='Original PSD')
    axs[0].plot(freqs, fooof_spectrum, label='SpecParam')
    # axs[0].plot(freqs, fooof_peak, label='SpecParam Peaks')
    axs[0].plot(freqs, fooof_ap, label='SpecParam Aperiodic')
    axs[0].set_title('SpecParam')
    axs[0].set_xlabel('Frequency (Hz)')
    axs[0].set_ylabel('Power (dB)')
    if iii == 0:
        axs[0].set_xscale('log')
    axs[0].legend()
    axs[1].plot(processed_freqs, processed_psd, label='Original PSD')
    axs[1].plot(freqs, our_spectrum, label='Our Method')
    # axs[1].plot(freqs, our_peak, label='Our Peaks')
    axs[1].plot(freqs, our_ap, label='Our Aperiodic')
    axs[1].set_title('Our Method')
    axs[1].set_xlabel('Frequency (Hz)')
    axs[1].set_ylabel('Power (dB)')
    if iii == 0:
        axs[1].set_xscale('log')
    axs[1].legend()
    print(f"Subject: {subj}, State: {state}, Channel: {channel}")
    plt.show()
# Out:
# PSD shape: (10, 19, 2498)
# Subject: 39, State: open, Channel: Cz
# Subject: 39, State: open, Channel: Cz

# %%
ex_param_spectra = extract_param_spectra(freqs, np.mean(psd, axis=0)[chdx], bands='standard_nohigh', log_freqs=True)
ex_param_spectra_ap = ex_param_spectra.get_params_out()['aperiodic_params']
ex_param_spectra_gaussian = ex_param_spectra.get_params_out()['gaussian_params']
plt.plot(freqs, np.log10(np.mean(psd, axis=0)[chdx]), label='Original')
ex_spectrum, ex_peak, ex_ap = reconstruct_bandparam_spectrum(freqs, ex_param_spectra_ap, ex_param_spectra_gaussian, standard_bands)
plt.plot(freqs, ex_spectrum, label='Reconstructed')
# plt.plot(freqs, ex_peak, label='Reconstructed Peaks')
# plt.plot(freqs, ex_ap, label='Reconstructed Aperiodic')
plt.plot(freqs, ex_param_spectra.modeled_spectrum_, label='Modeled Spectrum')
# plt.plot(freqs, ex_param_spectra._ap_fit, label='Aperiodic Fit')
# plt.plot(freqs, ex_param_spectra._peak_fit, label='Gaussian Fit')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Log Power')
plt.legend()
plt.title(f'{subj} {state} {channel}')
plt.show()
